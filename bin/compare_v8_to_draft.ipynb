# %% [markdown]
# The notebook is to genreate a list of reactions that have GPRs in the draft reconstruction, but are not present in the current version of the model. The idea is that if there is strong genomic evidence, aka an annotation already in Kegg, that fufills the acribed reaction in the draft reconstruction, it should also be included in the curated reconstruction.

# %%
#this is to parse through the draft reconstruction to get all of the original gene associated proposed by modelseed
import cobra
import bs4
from bs4 import BeautifulSoup

# %%
with open("../data/previous_data_from_curation/PSY_02.sbml") as fp:
    soup = BeautifulSoup(fp)

# %%
draft_gprs = {}
for reaction_tag in soup.listofreactions:
    string_list = str(reaction_tag).splitlines()
    for x in string_list:
        if "reaction id" in x:
            y = x[16:24]
        if "GENE_ASSOCIATION" in x:
            z = x[25: -9]
        draft_gprs[y] = z
# Out:
# rxn02201
# (PSPTO_4496 or (PSPTO_1041 or PSPTO_1748))
# rxn00351
# PSPTO_5035
# rxn00836
# PSPTO_1131
# rxn00390
# PSPTO_3295
# rxn08180
# PSPTO_0494
# rxn00062
# (PSPTO_1349 or PSPTO_1455)
# rxn00423
# (PSPTO_5178 or PSPTO_1421)
# rxn00364
# PSPTO_1749
# rxn05561
# (PSPTO_1051 or PSPTO_4063)
# rxn03505
# PSPTO_3668
# rxn03408
# PSPTO_4408
# rxn02177
# (PSPTO_1354 or PSPTO_1356 or PSPTO_1859 or PSPTO_2039)
# rxn05250
# (PSPTO_4685 or PSPTO_2991 or PSPTO_4097 or PSPTO_4098)
# rxn00646
# PSPTO_0325
# rxn05440
# PSPTO_3721
# rxn00935
# PSPTO_1136
# rxn01673
# PSPTO_1430
# rxn00247
# PSPTO_0239
# rxn05625
# PSPTO_2304
# rxn02342
# (PSPTO_5005 or PSPTO_3860 or PSPTO_3862)
# rxn00642
# PSPTO_1005
# rxn00973
# (Unknown and Unknown and PSPTO_3752 and PSPTO_3752 and PSPTO_2016)
# rxn02000
# (PSPTO_1077 or PSPTO_5397)
# rxn03239
# ((PSPTO_3517 and Unknown) or PSPTO_3517)
# rxn05063
# PSPTO_1930
# rxn05457
# (PSPTO_3833 or PSPTO_5081)
# rxn04271
# (PSPTO_4103 or PSPTO_2176)
# rxn13783
# (PSPTO_0656 and PSPTO_3658 and PSPTO_3826 and PSPTO_3514 and PSPTO_1549 and PSPTO_4814 and PSPTO_1812 and PSPTO_5516 and PSPTO_1745 and Unknown and PSPTO_0004 and Unknown and Unknown and PSPTO_4960 and PSPTO_0538 and PSPTO_5137 and PSPTO_0001 and Unknown and PSPTO_1813 and PSPTO_4963 and PSPTO_3646 and Unknown and PSPTO_0002)
# rxn10118
# (Unknown and Unknown and Unknown and Unknown and Unknown and Unknown and Unknown and Unknown and Unknown and PSPTO_4648)
# rxn05392
# (PSPTO_1916 and (PSPTO_3830 or PSPTO_4683))
# rxn04070
# PSPTO_4214
# rxn00199
# PSPTO_3356
# rxn03433
# (PSPTO_3705 or PSPTO_3705)
# rxn10231
# (PSPTO_0984 or PSPTO_3463)
# rxn02944
# PSPTO_1832
# rxn01867
# PSPTO_0441
# rxn12637
# ((PSPTO_1533 or PSPTO_2362 or PSPTO_0280) or PSPTO_1271 or PSPTO_3788)
# rxn03046
# PSPTO_5250
# rxn09240
# (PSPTO_4433 and PSPTO_4432)
# rxn01219
# PSPTO_1749
# rxn00519
# PSPTO_0085
# rxn00258
# PSPTO_5040
# rxn00800
# (PSPTO_3360 or PSPTO_3360)
# rxn09177
# PSPTO_0085
# rxn00211
# (PSPTO_2891 or PSPTO_5585)
# rxn00179
# PSPTO_0800
# rxn01210
# (PSPTO_3814 and PSPTO_3814)
# rxn00730
# PSPTO_1528
# rxn00192
# (PSPTO_0324 or PSPTO_4399)
# rxn01218
# (PSPTO_3043 or PSPTO_2277)
# rxn05367
# ((PSPTO_4683 or PSPTO_3830) and PSPTO_1916)
# rxn03456
# PSPTO_3550
# rxn03360
# PSPTO_1508
# rxn00509
# PSPTO_2660
# rxn02898
# PSPTO_2742
# rxn05654
# (PSPTO_1051 or PSPTO_4063)
# rxn01199
# (PSPTO_2703 or PSPTO_2702)
# rxn08807
# PSPTO_5299
# rxn05614
# ((PSPTO_5261 or PSPTO_5189) and (PSPTO_5187 or PSPTO_5260 or PSPTO_5216) and Unknown)
# rxn00501
# PSPTO_0782
# rxn00257
# (PSPTOA0032 or PSPTO_1453 or PSPTO_2305)
# rxn10344
# (PSPTO_2271 or PSPTO_0750 or PSPTO_5279)
# rxn01547
# PSPTO_5153
# rxn10336
# (PSPTO_4349 or PSPTO_0095)
# rxn02320
# (PSPTO_4437 and Unknown)
# rxn03384
# PSPTO_5118
# rxn05167
# (PSPTO_3004 and (PSPTO_3003 or PSPTO_2399) and PSPTO_3005)
# rxn06488
# PSPTO_5299
# rxn02504
# PSPTO_0542
# rxn04082
# PSPTO_3278
# rxn03506
# PSPTO_3668
# rxn04996
# PSPTO_0809
# rxn00262
# PSPTO_4225
# rxn05404
# ((PSPTO_4683 or PSPTO_3830) and PSPTO_1916)
# rxn02796
# (PSPTO_5528 or PSPTO_4945 or PSPTO_0338)
# rxn10262
# (PSPTO_5536 or PSPTO_3022)
# rxn10126
# ((PSPTO_2197 and PSPTO_2198) or PSPTO_2195 or PSPTO_2196)
# rxn10209
# PSPTO_1520
# rxn10225
# (PSPTO_5541 or PSPTO_1539)
# rxn03463
# PSPTO_0699
# rxn00898
# PSPTO_5057
# rxn05444
# PSPTO_3721
# rxn10205
# PSPTO_1520
# rxn05040
# ((PSPTO_2668 or PSPTO_0696 or PSPTO_0692) and (PSPTO_0692 or PSPTO_2668))
# rxn05400
# (PSPTO_1916 and (PSPTO_4683 or PSPTO_3830))
# rxn00890
# PSPTO_0885
# rxn01636
# PSPTO_4399
# rxn02090
# (PSPTO_2668 or PSPTO_0696 or PSPTO_0692)
# rxn08556
# PSPTO_4170
# rxn01843
# (PSPTO_1441 or PSPTO_0517)
# rxn01750
# PSPTO_5270
# rxn02988
# PSPTO_3959
# rxn04792
# PSPTO_1558
# rxn01243
# PSPTO_2510
# rxn00165
# (PSPTO_1886 and PSPTO_1886)
# rxn10228
# (PSPTO_3463 or PSPTO_0984)
# rxn05814
# PSPTO_0075
# rxn05542
# (PSPTO_4536 or (PSPTO_2576 or PSPTO_3248 or PSPTO_4561 or PSPTO_4557 or PSPTO_4559 or PSPTO_4558))
# rxn00539
# (PSPTO_0727 or PSPTO_0726 or PSPTO_3360)
# rxn11726
# PSPTO_1559
# rxn00678
# PSPTO_5040
# rxn00001
# (PSPTO_4615 or PSPTO_0722)
# rxn01331
# (PSPTO_1287 or PSPTO_0386)
# rxn07741
# PSPTO_2944
# rxn05545
# (PSPTO_4536 or (PSPTO_2576 or PSPTO_3248 or PSPTO_4557 or PSPTO_4561 or PSPTO_4559 or PSPTO_4558))
# rxn00671
# PSPTO_0782
# rxn11268
# (PSPTO_4312 or PSPTO_3702)
# rxn00710
# PSPTO_2028
# rxn02305
# PSPTO_4799
# rxn00470
# (PSPTO_0209 or PSPTO_0225)
# rxn08817
# PSPTO_5299
# rxn00910
# PSPTO_5069
# rxn00953
# (PSPTO_2430 or PSPTO_2430)
# rxn11944
# PSPTO_4179
# rxn08296
# PSPTO_4026
# rxn05541
# (PSPTO_4536 or (PSPTO_4561 or PSPTO_4558 or PSPTO_4559 or PSPTO_4557 or PSPTO_2576 or PSPTO_3248))
# rxn00717
# PSPTO_1602
# rxn05647
# (PSPTO_0954 and Unknown and Unknown and Unknown and Unknown)
# rxn01297
# ((PSPTO_4651 or PSPTO_2655 or PSPTO_2862) or PSPTO_3661 or PSPTO_3660 or PSPTO_3660)
# rxn10254
# PSPTO_4026
# rxn05459
# (PSPTO_3833 or PSPTO_5081)
# rxn05453
# (PSPTO_5081 or PSPTO_3833)
# rxn01682
# ((PSPTO_0159 and PSPTO_0158) or PSPTO_5251)
# rxn08796
# PSPTO_5299
# rxn03142
# PSPTO_3554
# rxn03181
# PSPTO_3845
# rxn02586
# PSPTO_3752
# rxn01604
# PSPTO_3968
# rxn02331
# PSPTO_1553
# rxn06493
# (((PSPTO_1277 or PSPTO_0317) and PSPTO_1276) or (Unknown and Unknown and (PSPTO_0317 or PSPTO_1277)))
# rxn12846
# ((PSPTO_0280 or PSPTO_2362 or PSPTO_1533) or PSPTO_1271 or PSPTO_3788)
# rxn00337
# (PSPTO_1843 or PSPTO_0082)
# rxn05221
# PSPTO_5016
# rxn08308
# (PSPTO_5541 or PSPTO_1539)
# rxn00208
# PSPTO_4116
# rxn08823
# PSPTO_5299
# rxn05434
# PSPTO_3721
# rxn00140
# (PSPTO_4965 or PSPTO_0490)
# rxn05346
# ((PSPTO_1916 and (PSPTO_4683 or PSPTO_3830)) or PSPTO_2210)
# rxn00867
# (PSPTO_5275 or PSPTO_5274)
# rxn07680
# PSPTO_3517
# rxn03248
# (PSPTO_3164 or (PSPTO_0744 or PSPTO_2940 or PSPTO_3516))
# rxn08127
# PSPTO_3127
# rxn05516
# (PSPTO_2271 or PSPTO_0750 or PSPTO_5279)
# rxn05142
# PSPTO_1108
# rxn05733
# PSPTO_3902
# rxn00416
# PSPTO_1633
# rxn01830
# PSPTO_2637
# rxn09206
# (PSPTO_0984 or PSPTO_3463)
# rxn01134
# (PSPTO_2761 or PSPTO_2952)
# rxn02376
# (PSPTO_2199 or PSPTO_2510)
# rxn10147
# (Unknown and Unknown and PSPTO_2853 and Unknown)
# rxn09209
# (PSPTO_3463 or PSPTO_0984)
# rxn12512
# PSPTO_0085
# rxn08669
# ((PSPTO_0660 or PSPTO_2107) or PSPTO_3461)
# rxn00902
# PSPTO_1444
# rxn06672
# (PSPTO_0610 and (PSPTO_2921 or PSPTO_4861) and (PSPTO_2922 or PSPTO_2918 or PSPTO_4860) and Unknown)
# rxn02961
# PSPTO_4828
# rxn03872
# PSPTO_1559
# rxn00649
# (PSPTO_3902 or PSPTO_1692)
# rxn01739
# PSPTO_5127
# rxn02400
# (PSPTO_3043 or PSPTO_2277)
# rxn01268
# PSPTO_1748
# rxn01528
# PSPTO_3506
# rxn00641
# ((PSPTO_1232 or PSPTO_3530 or PSPTO_1230) or (PSPTO_1232 or PSPTO_1230 or PSPTO_3530))
# rxn00361
# (PSPTO_5557 or PSPTO_4432)
# rxn01974
# PSPTO_0224
# rxn01640
# PSPTO_5171
# rxn00242
# PSPTO_0073
# rxn12641
# ((PSPTO_0280 or PSPTO_2362 or PSPTO_1533) or PSPTO_1271 or PSPTO_3788)
# rxn00568
# ((PSPTO_2302 or PSPTO_3262) and Unknown and PSPTO_3263)
# rxn08971
# PSPTO_0917
# rxn13400
# PSPTO_2944
# rxn05104
# PSPTO_2045
# rxn01635
# PSPTO_0690
# rxn08471
# (PSPTO_3466 or PSPTO_1795)
# rxn03057
# PSPTO_1744
# rxn04384
# PSPTO_1711
# rxn03887
# (PSPTO_4547 or (PSPTO_5396 or PSPTO_1081))
# rxn00060
# PSPTO_0128
# rxn00225
# PSPTO_1669
# rxn05350
# (((PSPTO_3830 or PSPTO_4683) and PSPTO_1916) or PSPTO_2210)
# rxn09198
# PSPTO_4955
# rxn08838
# PSPTO_5299
# rxn00780
# (PSPTO_0201 or PSPTO_1653 or PSPTO_4556 or PSPTO_3280)
# rxn05064
# PSPTO_1930
# rxn00148
# PSPTO_4337
# rxn01102
# ((PSPTO_3280 or PSPTO_0201 or PSPTO_4556 or PSPTO_1653) or PSPTO_5521)
# rxn05569
# (PSPTO_0954 and Unknown)
# rxn05358
# (PSPTO_5081 or PSPTO_3833)
# rxn00100
# PSPTO_0923
# rxn02842
# PSPTO_1056
# rxn00789
# (Unknown and PSPTO_4938)
# rxn02374
# Unknown
# rxn05560
# (PSPTO_0954 and PSPTO_0956 and PSPTO_0956 and PSPTO_0954 and Unknown)
# rxn05437
# PSPTO_3721
# rxn05158
# (PSPTO_0661 or PSPTO_0662 or PSPTO_0663)
# rxn08976
# PSPTO_0917
# rxn00781
# PSPTO_1287
# rxn05319
# Unknown
# rxn00881
# (PSPTO_0659 or PSPTO_1419)
# rxn05408
# (PSPTO_5081 or PSPTO_3833)
# rxn10337
# (PSPTO_4349 or PSPTO_0095)
# rxn02412
# PSPTO_1335
# rxn00292
# PSPTO_1196
# rxn04722
# PSPTO_2944
# rxn02122
# PSPTO_3323
# rxn05401
# (PSPTO_4201 or PSPTO_3832 or PSPTO_3054 or PSPTO_4380 or PSPTO_2396)
# rxn02264
# PSPTO_0129
# rxn10116
# (PSPTO_1608 or PSPTO_4196)
# rxn10338
# (PSPTO_0095 or PSPTO_4349)
# rxn03185
# PSPTO_0699
# rxn09202
# PSPTO_4955
# rxn07177
# PSPTO_3675
# rxn01451
# ((Unknown and PSPTO_3517) or PSPTO_3517)
# rxn02687
# (PSPTO_2176 or PSPTO_4103)
# rxn03903
# PSPTO_4411
# rxn00097
# PSPTO_1509
# rxn05514
# PSPTO_0764
# rxn02212
# PSPTO_5126
# rxn07670
# PSPTO_5597
# rxn05116
# PSPTO_0552
# rxn02768
# PSPTO_2944
# rxn05324
# PSPTO_3721
# rxn10481
# (PSPTO_2271 or PSPTO_5279 or PSPTO_0750 or PSPTO_1996)
# rxn03535
# PSPTO_1708
# rxn00655
# PSPTO_0437
# rxn00692
# (PSPTO_4632 or PSPTO_0461 or PSPTO_2427)
# rxn01492
# (PSPTO_0955 and Unknown)
# rxn00802
# (PSPTO_0200 or PSPTO_0125)
# rxn02160
# PSPTO_0186
# rxn08802
# PSPTO_5299
# rxn01825
# PSPTO_3551
# rxn10230
# (PSPTO_0984 or PSPTO_3463)
# rxn05413
# (PSPTO_1916 and (PSPTO_3830 or PSPTO_4683))
# rxn00913
# (PSPTO_2277 or PSPTO_3043)
# rxn01997
# (PSPTO_1081 or PSPTO_5396)
# rxn08521
# (PSPTO_3733 or PSPTO_2453)
# rxn08809
# PSPTO_5299
# rxn03958
# PSPTO_1540
# rxn00259
# PSPTO_3829
# rxn00131
# PSPTO_4795
# rxn00345
# PSPTO_3295
# rxn05578
# PSPTO_5238
# rxn07219
# PSPTO_4307
# rxn00178
# (PSPTO_3164 or (PSPTO_0744 or PSPTO_2940 or PSPTO_3516) or PSPTO_0957)
# rxn01362
# (PSPTO_0080 or PSPTO_3811)
# rxn03174
# ((PSPTO_2035 or PSPTO_1182) or PSPTO_2578)
# rxn10125
# ((Unknown and PSPTO_5464) or PSPTO_2106)
# rxn05161
# ((PSPTO_4915 or PSPTO_4112) or PSPTO_4919 or (PSPTO_4917 or PSPTO_4110) or (PSPTO_4916 or PSPTO_2990 or PSPTO_4111) or (PSPTO_4918 or PSPTO_2989 or PSPTO_4109) or PSPTO_4108)
# rxn00549
# (PSPTO_5168 or PSPTO_0186)
# rxn03951
# (PSPTO_0552 or PSPTO_0552)
# rxn07875
# (PSPTO_4103 or PSPTO_2176)
# rxn05418
# (PSPTO_2396 or PSPTO_4380 or PSPTO_3054 or PSPTO_3832 or PSPTO_4201)
# rxn00506
# (PSPTO_0418 or PSPTO_0728 or PSPTO_1881 or PSPTO_2673 or PSPTO_3064 or PSPTO_0092)
# rxn11723
# PSPTO_1559
# rxn10060
# PSPTO_3793
# rxn02933
# ((PSPTO_3517 and Unknown) or PSPTO_3517)
# rxn02261
# PSPTO_3705
# rxn00727
# ((PSPTO_0592 and PSPTO_0568) or PSPTO_2287)
# rxn05617
# (Unknown and PSPTO_0954 and Unknown and Unknown and Unknown)
# rxn12638
# ((PSPTO_2362 or PSPTO_1533 or PSPTO_0280) or PSPTO_1271 or PSPTO_3788)
# rxn05243
# PSPTO_2206
# rxn05127
# (PSPTO_2176 or PSPTO_4103)
# rxn00305
# PSPTO_0085
# rxn01445
# (PSPTO_3043 or PSPTO_2277)
# rxn05248
# (PSPTO_2991 or PSPTO_4685 or PSPTO_4097 or PSPTO_4098)
# rxn00612
# (PSPTO_2213 or PSPTO_2213)
# rxn05539
# (PSPTO_4536 or (PSPTO_4561 or PSPTO_4558 or PSPTO_4559 or PSPTO_4557 or PSPTO_2576 or PSPTO_3248))
# rxn08841
# PSPTO_5299
# rxn05461
# (PSPTO_4380 or PSPTO_3054 or PSPTO_3832 or PSPTO_2396 or PSPTO_4201)
# rxn07312
# PSPTO_5282
# rxn01701
# PSPTO_1169
# rxn02159
# (PSPTO_4438 or PSPTO_4438)
# rxn01111
# PSPTO_3143
# rxn10222
# (PSPTO_1539 or PSPTO_5541)
# rxn00269
# PSPTO_0817
# rxn10263
# (PSPTO_5536 or PSPTO_3022)
# rxn02791
# PSPTO_0787
# rxn05466
# (PSPTO_2586 or PSPTO_0218)
# rxn08814
# PSPTO_5299
# rxn08845
# PSPTO_5299
# rxn01292
# (PSPTO_1232 or PSPTO_4913 or PSPTO_3530 or PSPTO_1230)
# rxn00375
# PSPTO_5278
# rxn00300
# (PSPTO_0692 or PSPTO_0696 or PSPTO_2668)
# rxn02380
# PSPTO_0959
# rxn02026
# (PSPTO_0490 or PSPTO_4965)
# rxn00999
# ((PSPTO_3553 or PSPTO_2346) or (PSPTO_3553 or PSPTO_2346))
# rxn05417
# ((PSPTO_4683 or PSPTO_3830) and PSPTO_1916)
# rxn08799
# PSPTO_5299
# rxn05049
# PSPTO_3705
# rxn05585
# (PSPTO_1796 and (PSPTO_1791 or PSPTO_1788) and PSPTO_1797)
# rxn00433
# ((PSPTO_0458 or PSPTO_2450) and (PSPTO_2452 or PSPTO_0460))
# rxn01804
# PSPTO_2179
# rxn01157
# (PSPTO_1335 or PSPTO_1747)
# rxn05957
# PSPTO_3810
# rxn04135
# PSPTO_4877
# rxn03419
# ((PSPTO_1182 or PSPTO_2035) or PSPTO_2578)
# rxn08551
# PSPTO_1520
# rxn10256
# PSPTO_4026
# rxn00679
# PSPTO_2288
# rxn00758
# ((PSPTO_2107 or PSPTO_0660) or PSPTO_3461)
# rxn02975
# PSPTO_1196
# rxn04743
# PSPTO_2944
# rxn00638
# (PSPTO_1243 or PSPTO_1243)
# rxn09111
# (PSPTO_3022 or PSPTO_5536)
# rxn12432
# (PSPTO_5079 and PSPTO_5080)
# rxn01746
# PSPTO_3668
# rxn06078
# PSPTO_3810
# rxn05607
# (PSPTO_0890 or (Unknown and Unknown and Unknown and PSPTO_0954))
# rxn03848
# (PSPTO_1598 or PSPTO_0177)
# rxn05348
# (((PSPTO_4683 or PSPTO_3830) and PSPTO_1916) or PSPTO_2210)
# rxn10181
# PSPTO_3142
# rxn05435
# PSPTO_3721
# rxn00798
# PSPTO_3816
# rxn03245
# PSPTO_3517
# rxn11946
# PSPTO_1742
# rxn01504
# (PSPTO_2737 or PSPTO_2737)
# rxn00907
# ((PSPTO_2453 or PSPTO_3733) and (PSPTO_3733 or PSPTO_2453))
# rxn05458
# (PSPTO_3833 or PSPTO_5081)
# rxn08300
# PSPTO_4026
# rxn02404
# PSPTO_4449
# rxn08297
# PSPTO_4026
# rxn02911
# PSPTO_3517
# rxn00012
# PSPTO_4921
# rxn10067
# (PSPTO_3466 or PSPTO_1795)
# rxn02444
# PSPTO_0165
# rxn05581
# PSPTO_4167
# rxn07721
# PSPTO_5597
# rxn05450
# PSPTO_3721
# rxn12847
# ((PSPTO_0280 or PSPTO_1533 or PSPTO_2362) or PSPTO_1271 or PSPTO_3788)
# rxn05410
# (PSPTO_4201 or PSPTO_2396 or PSPTO_4380 or PSPTO_3054 or PSPTO_3832)
# rxn05443
# PSPTO_3721
# rxn09320
# PSPTO_1130
# rxn09114
# (PSPTO_3022 or PSPTO_5536)
# rxn05535
# (PSPTO_4536 or (PSPTO_4561 or PSPTO_4559 or PSPTO_4557 or PSPTO_4558 or PSPTO_3248 or PSPTO_2576))
# rxn08822
# PSPTO_5299
# rxn02821
# (PSPTO_3170 or PSPTO_3694 or PSPTO_3318)
# rxn10208
# PSPTO_1520
# rxn04630
# PSPTO_2709
# rxn05345
# ((PSPTO_1916 and (PSPTO_4683 or PSPTO_3830)) or PSPTO_2210)
# rxn04068
# (PSPTO_0338 or PSPTO_5528 or PSPTO_4945)
# rxn01522
# ((PSPTO_2655 or PSPTO_4651 or PSPTO_2862) or (PSPTO_3660 and PSPTO_3661 and PSPTO_3660))
# rxn00336
# PSPTO_3364
# rxn05422
# (PSPTO_2396 or PSPTO_4380 or PSPTO_3832 or PSPTO_3054 or PSPTO_4201)
# rxn01465
# ((PSPTO_4157 or PSPTO_5041) or PSPTO_5277)
# rxn03052
# PSPTO_4179
# rxn10204
# PSPTO_1520
# rxn05145
# ((PSPTO_3267 or PSPTO_5485) and (PSPTO_3266 or PSPTO_5484) and (PSPTO_5486 or PSPTO_3268) and (PSPTO_5487 or PSPTO_3269))
# rxn01872
# PSPTO_2200
# rxn01301
# (PSPTO_1480 or PSPTO_1480)
# rxn01643
# ((PSPTO_2176 or PSPTO_4103) or (PSPTO_2176 or PSPTO_4103))
# rxn04457
# Unknown
# rxn07574
# PSPTO_2944
# rxn00295
# (PSPTO_1754 or PSPTO_2900 or PSPTO_0678)
# rxn08844
# PSPTO_5299
# rxn05385
# (PSPTO_4201 or PSPTO_3832 or PSPTO_3054 or PSPTO_4380 or PSPTO_2396)
# rxn00707
# PSPTO_1749
# rxn06937
# PSPTO_2166
# rxn01637
# PSPTO_2618
# rxn05564
# PSPTO_5356
# rxn03095
# (PSPTO_0338 or PSPTO_5528 or PSPTO_4945)
# rxn00566
# (PSPTO_0701 or PSPTO_4265)
# rxn00708
# (PSPTO_2277 or PSPTO_3043)
# rxn00289
# PSPTO_2287
# rxn03762
# PSPTO_4441
# rxn01269
# PSPTO_1748
# rxn00392
# (PSPTO_0805 and PSPTO_0805)
# rxn00747
# (PSPTO_3493 or PSPTO_4494)
# rxn01334
# PSPTO_0390
# rxn03807
# PSPTO_2944
# rxn01108
# (PSPTO_2492 or PSPTO_2492)
# rxn05219
# (Unknown and (PSPTO_5189 or PSPTO_5261) and (PSPTO_5187 or PSPTO_5260 or PSPTO_5216))
# rxn10113
# (PSPTO_1325 or PSPTO_1327 or PSPTO_1328 or PSPTO_1326 or (PSPTO_4647 and PSPTO_4648) or (Unknown and PSPTO_2195 and Unknown and Unknown and Unknown))
# rxn00879
# (PSPTO_2722 or PSPTO_3492 or PSPTO_3019 or PSPTO_3047)
# rxn03406
# PSPTO_0359
# rxn00029
# PSPTO_5251
# rxn06673
# (PSPTO_1550 and PSPTO_3815)
# rxn07734
# PSPTO_5597
# rxn12646
# ((PSPTO_0280 or PSPTO_2362 or PSPTO_1533) or PSPTO_1271 or PSPTO_3788)
# rxn06777
# ((Unknown and PSPTO_3517) or PSPTO_3517)
# rxn03869
# (PSPTO_1441 or PSPTO_0517)
# rxn05256
# (PSPTO_2280 and Unknown)
# rxn05448
# PSPTO_3721
# rxn05446
# PSPTO_3721
# rxn02175
# PSPTO_0417
# rxn01634
# PSPTO_4549
# rxn00020
# ((PSPTO_3318 or PSPTO_3694 or PSPTO_3170) or PSPTO_4290)
# rxn02835
# (PSPTO_5153 and PSPTO_5154)
# rxn03440
# PSPTO_3517
# rxn03884
# (PSPTO_1302 and PSPTO_1302)
# rxn04385
# PSPTO_1712
# rxn01675
# PSPTO_1079
# rxn00324
# ((PSPTO_2434 or PSPTO_1215) and (PSPTO_2434 or PSPTO_1215))
# rxn08839
# PSPTO_5299
# rxn03289
# PSPTO_3517
# rxn03536
# PSPTO_1714
# rxn00149
# PSPTO_2680
# rxn01575
# PSPTO_1332
# rxn05150
# ((PSPTO_2633 or PSPTO_5266) and Unknown and Unknown)
# rxn00656
# (PSPTO_5308 or PSPTO_0774)
# rxn10335
# (PSPTO_0095 or PSPTO_4349)
# rxn02009
# PSPTO_5227
# rxn01315
# PSPTO_1822
# rxn01868
# PSPTO_0441
# rxn03240
# PSPTO_3517
# rxn09562
# PSPTO_0075
# rxn05359
# (PSPTO_1916 and (PSPTO_4683 or PSPTO_3830))
# rxn06098
# PSPTO_0495
# rxn00555
# PSPTO_1779
# rxn03282
# (PSPTO_2182 or PSPTO_2697 or PSPTO_1337 or PSPTO_4285 or PSPTO_2957)
# rxn01828
# PSPTO_3772
# rxn03080
# PSPTO_0693
# rxn10237
# PSPTO_4955
# rxn01044
# (PSPTO_3002 or PSPTO_0959)
# rxn07845
# PSPTO_3285
# rxn12644
# ((PSPTO_2362 or PSPTO_1533 or PSPTO_0280) or PSPTO_1271 or PSPTO_3788)
# rxn00147
# (PSPTO_5448 or PSPTO_2292)
# rxn00737
# (PSPTO_3806 or PSPTO_5288)
# rxn05292
# (PSPTO_3598 and (PSPTO_3597 or PSPTO_3599))
# rxn08843
# PSPTO_5299
# rxn04723
# (PSPTO_4103 or PSPTO_2176)
# rxn01256
# PSPTO_0357
# rxn00213
# PSPTO_3113
# rxn10162
# (PSPTO_1720 or PSPTO_0893)
# rxn00777
# PSPTO_5289
# rxn05164
# (PSPTO_4137 or (PSPTO_4140 or PSPTO_5357) or PSPTO_4138)
# rxn13784
# (Unknown and Unknown and PSPTO_1639 and Unknown and PSPTO_0619 and Unknown and PSPTO_0537 and Unknown and PSPTO_4217 and PSPTO_4491 and PSPTO_5614 and PSPTO_0620 and PSPTO_0651)
# rxn01740
# (PSPTO_0169 or PSPTO_2348 or PSPTO_2685)
# rxn05533
# (PSPTO_4536 or (PSPTO_3248 or PSPTO_2576 or PSPTO_4561 or PSPTO_4557 or PSPTO_4559 or PSPTO_4558))
# rxn02642
# PSPTO_2309
# rxn00968
# PSPTO_3051
# rxn05327
# PSPTO_3721
# rxn04841
# (PSPTO_1719 or PSPTO_1781 or PSPTO_1172)
# rxn01013
# ((PSPTO_2434 or PSPTO_1215) or (PSPTO_1215 or PSPTO_2434))
# rxn05655
# (PSPTO_0954 and Unknown and Unknown and Unknown)
# rxn02314
# (Unknown and PSPTO_0955)
# rxn08801
# PSPTO_5299
# rxn02275
# (PSPTO_0517 or PSPTO_1441)
# rxn05244
# PSPTO_2206
# rxn00503
# PSPTO_5017
# rxn00927
# (PSPTO_2373 or PSPTO_5068)
# rxn00251
# PSPTO_1508
# rxn01545
# PSPTO_2373
# rxn04043
# PSPTO_2371
# rxn03508
# PSPTO_3668
# rxn00139
# PSPTO_1990
# rxn07261
# PSPTO_4411
# rxn00920
# (PSPTO_0490 or PSPTO_4965)
# rxn00790
# (PSPTO_3811 or PSPTO_0593)
# rxn03910
# PSPTO_1560
# rxn00237
# PSPTO_1430
# rxn07100
# PSPTO_4411
# rxn10342
# (PSPTO_0095 or PSPTO_4349)
# rxn03540
# PSPTO_1713
# rxn08311
# (PSPTO_1539 or PSPTO_5541)
# rxn03175
# PSPTO_5335
# rxn10264
# (PSPTO_3022 or PSPTO_5536)
# rxn03421
# ((PSPTO_1182 or PSPTO_2035) or PSPTO_2578)
# rxn10227
# (PSPTO_3463 or PSPTO_0984)
# rxn01146
# PSPTO_0949
# rxn05336
# (PSPTO_4380 or PSPTO_3832 or PSPTO_3054 or PSPTO_2396 or PSPTO_4201)
# rxn09210
# (PSPTO_0984 or PSPTO_3463)
# rxn06022
# PSPTO_4355
# rxn02260
# PSPTO_3705
# rxn01124
# (PSPTO_1056 or PSPTO_1056)
# rxn00285
# (PSPTO_2203 and PSPTO_2202)
# rxn05371
# ((PSPTO_4683 or PSPTO_3830) and PSPTO_1916)
# rxn07584
# PSPTO_0595
# rxn00182
# PSPTO_3757
# rxn05552
# (PSPTO_1797 and (PSPTO_1788 or PSPTO_1791) and PSPTO_1796)
# rxn01416
# PSPTO_0548
# rxn05567
# (Unknown and Unknown and PSPTO_0954 and Unknown and Unknown)
# rxn02181
# (PSPTO_3517 or PSPTO_1288)
# rxn00532
# (PSPTO_2176 or PSPTO_4103)
# rxn05172
# (((PSPTO_1788 or PSPTO_1791) and PSPTO_1796 and PSPTO_1797) or (PSPTO_5320 or PSPTO_5197) or (PSPTO_5319 or PSPTO_2486 or PSPTO_5195) or (PSPTO_5321 or PSPTO_5196))
# rxn01642
# PSPTO_5277
# rxn00132
# (PSPTO_3043 or PSPTO_2277)
# rxn11724
# PSPTO_1559
# rxn01204
# (PSPTO_1890 or PSPTO_0301 or PSPTO_0259)
# rxn04052
# (PSPTO_3035 or PSPTO_0083)
# rxn08954
# PSPTO_2767
# rxn02819
# PSPTO_0961
# rxn13999
# PSPTO_2944
# rxn01479
# PSPTO_4828
# rxn08615
# PSPTO_3125
# rxn12850
# (PSPTO_4536 or (PSPTO_4557 or PSPTO_4561 or PSPTO_4559 or PSPTO_4558 or PSPTO_2576 or PSPTO_3248))
# rxn08815
# PSPTO_5299
# rxn00472
# PSPTO_3517
# rxn00126
# PSPTO_0383
# rxn01015
# (PSPTO_3048 or PSPTO_5064)
# rxn12844
# ((PSPTO_2362 or PSPTO_1533 or PSPTO_0280) or PSPTO_1271 or PSPTO_3788)
# rxn08798
# PSPTO_5299
# rxn05175
# (PSPTO_5302 and Unknown and Unknown and Unknown and Unknown and PSPTO_5303 and PSPTO_5301)
# rxn08618
# PSPTO_5001
# rxn05034
# PSPTO_5476
# rxn02584
# PSPTO_4034
# rxn08306
# (PSPTO_5541 or PSPTO_1539)
# rxn08821
# PSPTO_5299
# rxn00206
# (PSPTO_4363 or PSPTO_1338 or PSPTO_4459)
# rxn01871
# PSPTO_5006
# rxn05340
# (PSPTO_4201 or PSPTO_2396 or PSPTO_3832 or PSPTO_3054 or PSPTO_4380)
# rxn13952
# PSPTO_2309
# rxn00484
# PSPTO_1508
# rxn00405
# PSPTO_4842
# rxn04704
# PSPTO_1993
# rxn05307
# PSPTO_1760
# rxn01169
# PSPTO_1289
# rxn14301
# PSPTO_2119
# rxn00299
# ((PSPTO_1182 or PSPTO_2035) or PSPTO_2578)
# rxn08546
# PSPTO_1520
# rxn00756
# PSPTO_0165
# rxn05389
# (PSPTO_2396 or PSPTO_4380 or PSPTO_3054 or PSPTO_3832 or PSPTO_4201)
# rxn08900
# PSPTO_1136
# rxn07230
# PSPTO_5401
# rxn04737
# (PSPTO_2176 or PSPTO_4103)
# rxn02379
# (PSPTO_0836 or PSPTO_3590)
# rxn05735
# (PSPTO_0092 or PSPTO_3064 or PSPTO_2673 or PSPTO_1881 or PSPTO_0728 or PSPTO_0418)
# rxn07578
# PSPTO_2944
# rxn03921
# (PSPTO_4103 or PSPTO_2176)
# rxn11587
# PSPTO_0885
# rxn00904
# PSPTO_0970
# rxn02484
# PSPTO_4798
# rxn00013
# PSPTO_2782
# rxn02916
# Unknown
# rxn03618
# (PSPTO_4103 or PSPTO_2176)
# rxn12639
# ((PSPTO_0280 or PSPTO_1533 or PSPTO_2362) or PSPTO_1271 or PSPTO_3788)
# rxn03159
# PSPTO_1547
# rxn01000
# (PSPTO_1335 or PSPTO_1747)
# rxn00363
# (PSPTO_2277 or PSPTO_3043)
# rxn01462
# PSPTO_1602
# rxn08128
# PSPTO_3127
# rxn00705
# PSPTO_2782
# rxn01670
# (PSPTO_2277 or PSPTO_3043)
# rxn12643
# ((PSPTO_1533 or PSPTO_2362 or PSPTO_0280) or PSPTO_1271 or PSPTO_3788)
# rxn05183
# ((PSPTO_5187 or PSPTO_5260 or PSPTO_5216) and (PSPTO_5189 or PSPTO_5261) and Unknown)
# rxn01904
# PSPTO_4876
# rxn01300
# (PSPTO_2281 or PSPTO_0346)
# rxn02334
# (PSPTO_4965 or PSPTO_0490)
# rxn02173
# (PSPTO_2179 or PSPTO_2179)
# rxn00786
# PSPTO_0390
# rxn01572
# PSPTO_3991
# rxn14054
# (PSPTO_2697 or PSPTO_2182 or PSPTO_4285 or PSPTO_2957 or PSPTO_1337)
# rxn03012
# Unknown
# rxn10195
# (Unknown and PSPTO_0705)
# rxn03908
# PSPTO_1105
# rxn09197
# PSPTO_4955
# rxn01100
# PSPTO_0387
# rxn00838
# PSPTO_4937
# rxn08707
# PSPTO_1329
# rxn02283
# PSPTO_0178
# rxn03287
# PSPTO_3517
# rxn00512
# (((PSPTO_2434 or PSPTO_1215) and (PSPTO_1215 or PSPTO_2434)) or (PSPTO_1215 or PSPTO_2434))
# rxn05396
# (PSPTO_1916 and (PSPTO_4683 or PSPTO_3830))
# rxn00831
# (PSPTO_3043 or PSPTO_2277)
# rxn12634
# ((PSPTO_0280 or PSPTO_1533 or PSPTO_2362) or PSPTO_1271 or PSPTO_3788)
# rxn00883
# (PSPTO_0659 or PSPTO_1419)
# rxn01255
# PSPTO_2043
# rxn05872
# (PSPTO_2182 or PSPTO_2697 or PSPTO_1337 or PSPTO_2957 or PSPTO_4285)
# rxn04727
# (PSPTO_4103 or PSPTO_2176)
# rxn00776
# (PSPTO_4247 and PSPTO_3840 and Unknown and PSPTO_0827 and PSPTO_1815 and PSPTO_4794)
# rxn05251
# (PSPTO_4097 or PSPTO_4098 or PSPTO_4685 or PSPTO_2991)
# rxn05485
# (PSPTO_0954 and Unknown and Unknown and Unknown)
# rxn14089
# (PSPTO_2957 or PSPTO_4285 or PSPTO_1337 or PSPTO_2697 or PSPTO_2182)
# rxn00214
# (PSPTO_1754 or PSPTO_2900 or PSPTO_0678)
# rxn01211
# ((PSPTO_2453 or PSPTO_3733) and (PSPTO_3733 or PSPTO_2453))
# rxn00527
# ((PSPTO_2925 or PSPTO_5504) or (PSPTO_2163 or PSPTO_5339) or (Unknown and PSPTO_4437))
# rxn00095
# PSPTO_0549
# rxn05322
# PSPTO_3721
# rxn12848
# (PSPTO_4536 or (PSPTO_4561 or PSPTO_4558 or PSPTO_4559 or PSPTO_4557 or PSPTO_3248 or PSPTO_2576))
# rxn03537
# PSPTO_1714
# rxn01989
# PSPTO_3285
# rxn08804
# PSPTO_5299
# rxn00966
# PSPTO_5475
# rxn13782
# (PSPTO_0632 and Unknown and (PSPTO_1435 or PSPTO_2611) and PSPTO_0626 and PSPTO_0645 and PSPTO_0609 and PSPTO_4932 and PSPTO_3981 and PSPTO_4429 and PSPTO_5615 and PSPTO_4425 and PSPTO_0633 and PSPTO_0639 and PSPTO_4812 and PSPTO_0798 and PSPTO_4426 and PSPTO_1551 and PSPTO_4933 and PSPTO_4930 and PSPTO_2380 and PSPTO_2378 and (PSPTO_4183 or PSPTO_5136) and PSPTO_3742 and PSPTO_4147 and PSPTO_0616 and Unknown and PSPTO_1501 and PSPTO_0178 and PSPTO_0628 and PSPTO_0630 and PSPTO_2382 and PSPTO_3345 and PSPTO_0635 and PSPTO_0806 and PSPTO_0640 and PSPTO_0631 and PSPTO_0625 and PSPTO_0641 and PSPTO_0647 and PSPTO_0649 and PSPTO_4474 and PSPTO_4475 and PSPTO_0652 and PSPTO_0622 and (PSPTO_1268 or PSPTO_2264) and PSPTO_0185 and Unknown and PSPTO_5138 and PSPTO_0638 and PSPTO_0089 and PSPTO_0184 and PSPTO_0617 and PSPTO_1534 and PSPTO_0644 and PSPTO_0802 and PSPTO_3835 and PSPTO_1473 and PSPTO_0636 and PSPTO_0643 and PSPTO_1842 and PSPTO_0648 and PSPTO_4487 and PSPTO_0642 and PSPTO_0539 and PSPTO_0629 and PSPTO_0650 and PSPTO_2381 and PSPTO_4473 and PSPTO_2166 and PSPTO_0637 and PSPTO_2383 and PSPTO_0797 and PSPTO_0627 and PSPTO_1476 and PSPTO_0634 and PSPTO_0621 and PSPTO_0090)
# rxn04270
# (PSPTO_2176 or PSPTO_4103)
# rxn05430
# (PSPTO_4380 or PSPTO_3054 or PSPTO_3832 or PSPTO_2396 or PSPTO_4201)
# rxn06099
# (PSPTO_2470 or PSPTO_1345 or PSPTO_1052)
# rxn11838
# (PSPTO_1337 or PSPTO_2957 or PSPTO_4285 or PSPTO_2182 or PSPTO_2697)
# rxn01580
# PSPTO_1892
# rxn01917
# (PSPTO_0082 or PSPTO_0082)
# rxn10236
# PSPTO_4955
# rxn02429
# PSPTO_2177
# rxn08527
# (PSPTO_2197 or (Unknown and PSPTO_2196 and Unknown and PSPTO_2195 and Unknown and Unknown) or (PSPTO_2197 and PSPTO_2198))
# rxn05501
# (PSPTO_0954 and Unknown and Unknown and Unknown and Unknown)
# rxn01509
# (PSPTO_0075 or PSPTO_0075)
# rxn02011
# PSPTO_4413
# rxn00173
# PSPTO_1169
# rxn08528
# (PSPTO_2197 or (PSPTO_2196 and Unknown and Unknown and PSPTO_2195 and Unknown and Unknown) or (PSPTO_2197 and PSPTO_2198))
# rxn01145
# (PSPTO_2277 or PSPTO_3043)
# rxn09205
# (PSPTO_3463 or PSPTO_0984)
# rxn05163
# (PSPTO_5302 and Unknown and Unknown and Unknown and Unknown and PSPTO_5303 and PSPTO_5301)
# rxn05364
# (PSPTO_4201 or PSPTO_3054 or PSPTO_3832 or PSPTO_4380 or PSPTO_2396)
# rxn01854
# PSPTO_5278
# rxn09201
# PSPTO_4955
# rxn05574
# PSPTO_5219
# rxn05202
# PSPTO_0772
# rxn00508
# PSPTO_2660
# rxn03035
# PSPTO_5401
# rxn02115
# PSPTO_0566
# rxn10122
# (PSPTO_3370 and PSPTO_3375 and PSPTO_3372 and PSPTO_3374 and PSPTO_3368 and PSPTO_3376 and PSPTO_3371 and PSPTO_3373 and PSPTO_3367 and PSPTO_3365 and PSPTO_3369 and PSPTO_3377 and PSPTO_3366 and PSPTO_3367)
# rxn05547
# (PSPTO_4536 or (PSPTO_4557 or PSPTO_4561 or PSPTO_4559 or PSPTO_4558 or PSPTO_2576 or PSPTO_3248))
# rxn11721
# PSPTO_1559
# rxn08352
# PSPTO_0809
# rxn00187
# PSPTO_0359
# rxn00376
# PSPTO_3295
# rxn02466
# PSPTO_2944
# rxn08850
# PSPTO_5299
# rxn05734
# (PSPTO_0092 or PSPTO_3064 or PSPTO_2673 or PSPTO_0418 or PSPTO_0728 or PSPTO_1881)
# rxn00772
# PSPTO_2371
# rxn02229
# PSPTO_0494
# rxn00721
# PSPTO_1532
# rxn08812
# PSPTO_5299
# rxn05682
# PSPTO_1871
# rxn02503
# (PSPTO_0543 or PSPTO_0962)
# rxn05338
# (PSPTO_2396 or PSPTO_3054 or PSPTO_3832 or PSPTO_4380 or PSPTO_4201)
# rxn02262
# PSPTO_0955
# rxn03135
# (Unknown and PSPTO_5337)
# rxn12146
# PSPTO_3498
# rxn01345
# PSPTO_0186
# rxn05429
# (PSPTO_1916 and (PSPTO_4683 or PSPTO_3830))
# rxn08310
# (PSPTO_5541 or PSPTO_1539)
# rxn00915
# PSPTO_1131
# rxn02853
# (PSPTO_3064 or PSPTO_0092 or PSPTO_1881 or PSPTO_0418 or PSPTO_0728 or PSPTO_2673)
# rxn01967
# ((PSPTO_0836 or PSPTO_3590) or (PSPTO_3590 or PSPTO_0836))
# rxn06752
# (PSPTO_3170 or PSPTO_3694 or PSPTO_3318)
# rxn10224
# (PSPTO_1539 or PSPTO_5541)
# rxn05337
# (PSPTO_2396 or PSPTO_4380 or PSPTO_3054 or PSPTO_3832 or PSPTO_4201)
# rxn01135
# PSPTO_1711
# rxn02067
# PSPTO_2309
# rxn01477
# PSPTO_1288
# rxn01653
# PSPTO_5227
# rxn00474
# ((PSPTO_0158 and PSPTO_0159) or PSPTO_5251)
# rxn03147
# (PSPTO_3950 or PSPTO_1700)
# rxn03843
# PSPTO_1538
# rxn05376
# (PSPTO_2396 or PSPTO_3832 or PSPTO_3054 or PSPTO_4380 or PSPTO_4201)
# rxn08557
# PSPTO_4170
# rxn01842
# (PSPTO_2941 or PSPTO_2942)
# rxn01802
# PSPTO_5461
# rxn11809
# (PSPTO_2697 or PSPTO_2182 or PSPTO_2957 or PSPTO_4285 or PSPTO_1337)
# rxn01116
# (PSPTO_0566 or (PSPTO_1077 or PSPTO_5397))
# rxn02182
# (PSPTO_0125 or PSPTO_0200)
# rxn02811
# (PSPTO_2174 or PSPTO_2173 or (PSPTO_2174 and PSPTO_2173))
# rxn03062
# (PSPTO_2175 or PSPTO_2175)
# rxn10258
# PSPTO_4026
# rxn08847
# PSPTO_5299
# rxn05608
# (PSPTO_0890 or (Unknown and Unknown and PSPTO_0886 and Unknown))
# rxn00670
# PSPTO_1169
# rxn01544
# (PSPTO_1131 or PSPTO_0112)
# rxn00863
# (PSPTO_4438 or PSPTO_4438)
# rxn09113
# (PSPTO_3022 or PSPTO_5536)
# rxn11719
# PSPTO_1559
# rxn00711
# (PSPTO_1130 and PSPTO_5039)
# rxn05557
# (PSPTO_0763 or PSPTO_0761 or PSPTO_0760)
# rxn10184
# (Unknown and PSPTO_0954 and Unknown and Unknown and Unknown)
# rxn01270
# ((PSPTO_5339 or PSPTO_2163) or PSPTO_1832)
# rxn00908
# PSPTO_1699
# rxn08299
# PSPTO_4026
# rxn08711
# PSPTO_5003
# rxn00795
# (PSPTO_0256 or PSPTO_0323)
# rxn14090
# PSPTO_4943
# rxn02402
# (PSPTO_0948 or PSPTO_0112)
# rxn05673
# PSPTO_5219
# rxn05452
# (PSPTO_5081 or PSPTO_3833)
# rxn01607
# PSPTO_2701
# rxn05465
# (PSPTO_5081 or PSPTO_3833)
# rxn12845
# ((PSPTO_1533 or PSPTO_2362 or PSPTO_0280) or PSPTO_1271 or PSPTO_3788)
# rxn08820
# PSPTO_5299
# rxn05380
# (PSPTO_2396 or PSPTO_4380 or PSPTO_3832 or PSPTO_3054 or PSPTO_4201)
# rxn05347
# (((PSPTO_4683 or PSPTO_3830) and PSPTO_1916) or PSPTO_2210)
# rxn04413
# PSPTO_1714
# rxn00404
# PSPTO_2119
# rxn08126
# PSPTO_3127
# rxn03407
# PSPTO_0359
# rxn08547
# PSPTO_1520
# rxn03050
# PSPTO_2944
# rxn05143
# PSPTO_1108
# rxn05388
# (PSPTO_1916 and (PSPTO_4683 or PSPTO_3830))
# rxn01404
# PSPTO_5117
# rxn01870
# PSPTO_0390
# rxn01303
# (PSPTO_5049 or PSPTO_4399)
# rxn08901
# PSPTO_1136
# rxn00113
# PSPTO_1552
# rxn04736
# (PSPTO_2957 or PSPTO_4285 or PSPTO_1337 or PSPTO_2697 or PSPTO_2182)
# rxn00497
# PSPTO_1508
# rxn07579
# PSPTO_3721
# rxn00297
# PSPTO_1196
# rxn00137
# PSPTO_5401
# rxn06023
# PSPTO_1675
# rxn00611
# (PSPTO_2213 or PSPTO_2213)
# rxn01678
# PSPTO_1430
# rxn00872
# PSPTO_2739
# rxn00832
# (PSPTO_4866 and PSPTO_4866)
# rxn05871
# (PSPTO_1337 or PSPTO_2957 or PSPTO_4285 or PSPTO_2182 or PSPTO_2697)
# rxn01106
# PSPTO_5327
# rxn12640
# ((PSPTO_1533 or PSPTO_2362 or PSPTO_0280) or PSPTO_1271 or PSPTO_3788)
# rxn00977
# PSPTO_0885
# rxn08438
# PSPTO_1559
# rxn00931
# PSPTO_5047
# rxn01188
# PSPTO_2944
# rxn02418
# (PSPTO_0436 or PSPTO_3883 or PSPTO_4957 or PSPTO_5286 or PSPTO_2281)
# rxn08756
# PSPTO_0809
# rxn08470
# (PSPTO_1795 or PSPTO_3466)
# rxn01456
# PSPTO_1053
# rxn09450
# (PSPTO_4097 or PSPTO_4098 or PSPTO_2991 or PSPTO_4685)
# rxn00938
# PSPTO_3295
# rxn04938
# PSPTO_1558
# rxn05527
# PSPTO_1871
# rxn00412
# (PSPTO_1552 or PSPTO_4155)
# rxn02339
# (PSPTO_2925 or PSPTO_5504)
# rxn00650
# ((PSPTO_2362 or PSPTO_1533 or PSPTO_0280) or PSPTO_1271 or PSPTO_3788)
# rxn05152
# ((PSPTO_2915 or PSPTO_4172) and PSPTO_4171 and (PSPTO_4173 or PSPTO_2914) and (PSPTO_4174 or PSPTO_2913))
# rxn02737
# (PSPTO_0678 or PSPTO_2900 or PSPTO_1754)
# rxn00515
# PSPTO_1430
# rxn08846
# PSPTO_5299
# rxn05397
# (PSPTO_4201 or PSPTO_4380 or PSPTO_3054 or PSPTO_3832 or PSPTO_2396)
# rxn03005
# PSPTO_1699
# rxn05012
# PSPTO_0385
# rxn03437
# PSPTO_5057
# rxn01353
# PSPTO_1430
# rxn10235
# PSPTO_4955
# rxn12633
# ((PSPTO_0280 or PSPTO_2362 or PSPTO_1533) or PSPTO_1271 or PSPTO_3788)
# rxn00882
# (PSPTO_1419 or PSPTO_0659)
# rxn03244
# ((PSPTO_3517 and Unknown) or PSPTO_3517)
# rxn00616
# PSPTO_4170
# rxn03347
# PSPTO_2944
# rxn04237
# PSPTO_2944
# rxn01639
# PSPTO_4866
# rxn05409
# (PSPTO_1916 and (PSPTO_3830 or PSPTO_4683))
# rxn03263
# PSPTO_5179
# rxn06723
# PSPTO_1544
# rxn00313
# (PSPTO_0225 or PSPTO_0209)
# rxn02949
# PSPTO_3517
# rxn06570
# PSPTO_1742
# rxn00735
# PSPTO_2175
# rxn04278
# PSPTO_1559
# rxn10160
# PSPTO_2180
# rxn00775
# PSPTO_4973
# rxn02680
# (PSPTO_3164 or (PSPTO_3516 or PSPTO_0744 or PSPTO_2940))
# rxn05405
# (PSPTO_4201 or PSPTO_2396 or PSPTO_4380 or PSPTO_3832 or PSPTO_3054)
# rxn10571
# Unknown
# rxn05363
# (PSPTO_1916 and (PSPTO_4683 or PSPTO_3830))
# rxn00547
# PSPTO_2701
# rxn01192
# (PSPTO_2339 or PSPTO_2338)
# rxn04750
# ((Unknown and PSPTO_3517) or PSPTO_3517)
# rxn05325
# PSPTO_3721
# rxn08647
# PSPTO_5521
# rxn11040
# PSPTO_3122
# rxn03842
# PSPTO_5393
# rxn10168
# (PSPTO_2243 or PSPTO_2242 or PSPTO_2244)
# rxn05610
# (Unknown and Unknown and PSPTO_0954 and Unknown and Unknown)
# rxn03366
# (PSPTO_2176 or PSPTO_4103)
# rxn02421
# PSPTO_1556
# rxn10042
# (Unknown and PSPTO_5601 and PSPTO_5600 and Unknown and PSPTO_5598 and PSPTO_5606 and PSPTO_5602 and PSPTO_5599 and Unknown)
# rxn08803
# PSPTO_5299
# rxn01053
# PSPTO_1891
# rxn02312
# PSPTO_5075
# rxn03422
# PSPTO_1835
# rxn02895
# PSPTO_4867
# rxn07295
# PSPTO_0817
# rxn01066
# (PSPTO_1052 or PSPTO_1345 or PSPTO_2470)
# rxn02934
# PSPTO_3517
# rxn07688
# PSPTO_3517
# rxn01814
# PSPTO_1140
# rxn00189
# PSPTO_2488
# rxn02508
# PSPTO_3816
# rxn05442
# PSPTO_3721
# rxn00543
# ((PSPTO_2182 or PSPTO_2697 or PSPTO_1337 or PSPTO_2957 or PSPTO_4285) or (PSPTO_2182 or PSPTO_2697 or PSPTO_1337 or PSPTO_2957 or PSPTO_4285))
# rxn01996
# (PSPTO_2261 or PSPTO_1874)
# rxn00428
# PSPTO_0230
# rxn10340
# (PSPTO_0095 or PSPTO_4349)
# rxn00420
# (PSPTO_2281 or PSPTO_5286 or PSPTO_4957 or PSPTO_3883 or PSPTO_0436)
# rxn09657
# PSPTO_1871
# rxn10253
# PSPTO_4026
# rxn10207
# PSPTO_1520
# rxn10221
# (PSPTO_5541 or PSPTO_1539)
# rxn02792
# PSPTO_0787
# rxn05451
# (PSPTO_3833 or PSPTO_5081)
# rxn00469
# ((PSPTO_0256 or PSPTO_0323) or PSPTO_2488)
# rxn02804
# (PSPTO_3164 or (PSPTO_2940 or PSPTO_0744 or PSPTO_3516))
# rxn02784
# PSPTO_4880
# rxn05005
# (PSPTO_3344 or PSPTO_2300)
# rxn00548
# PSPTO_1670
# rxn02795
# (PSPTO_0338 or PSPTO_5528 or PSPTO_4945)
# rxn10203
# PSPTO_1520
# rxn02939
# PSPTO_2019
# rxn04715
# PSPTO_2944
# rxn00048
# PSPTO_0691
# rxn07876
# (PSPTO_2176 or PSPTO_4103)
# rxn12191
# (PSPTO_2182 or PSPTO_2697 or PSPTO_1337 or PSPTO_4285 or PSPTO_2957)
# rxn05231
# (PSPTO_1661 or PSPTO_1671)
# rxn09200
# PSPTO_4955
# rxn00283
# PSPTO_0103
# rxn11722
# PSPTO_1559
# rxn00726
# ((PSPTO_0592 and PSPTO_0568) or PSPTO_2287)
# rxn00379
# (PSPTO_4433 or PSPTO_4432)
# rxn01025
# PSPTO_1602
# rxn08851
# PSPTO_5299
# rxn02155
# (PSPTO_4828 or (PSPTO_3530 or PSPTO_1230 or PSPTO_1232) or PSPTO_4828)
# rxn05549
# ((PSPTO_1161 or PSPTO_2369 or PSPTO_2400) and PSPTO_2367 and (PSPTO_2368 or PSPTO_2398) and Unknown)
# rxn02866
# PSPTO_2739
# rxn05975
# PSPTO_2680
# rxn01754
# (PSPTO_4168 or PSPTO_2403)
# rxn08552
# PSPTO_1520
# rxn05170
# (PSPTO_0890 or PSPTO_0886)
# rxn02475
# ((PSPTO_0690 and PSPTO_0690) or (PSPTO_3663 or PSPTO_0765))
# rxn01273
# PSPTO_2680
# rxn05339
# (PSPTO_4201 or PSPTO_4380 or PSPTO_3054 or PSPTO_3832 or PSPTO_2396)
# rxn05460
# ((PSPTO_3830 or PSPTO_4683) and PSPTO_1916)
# rxn03108
# PSPTO_4798
# rxn07449
# PSPTO_3106
# rxn01018
# PSPTO_5040
# rxn04132
# Unknown
# rxn00714
# PSPTO_0600
# rxn08813
# PSPTO_5299
# rxn05506
# PSPTO_3798
# rxn00124
# (PSPTO_5521 or (PSPTO_2281 or PSPTO_0346))
# rxn11801
# PSPTO_1559
# rxn00634
# (PSPTO_0363 or PSPTO_0834)
# rxn00947
# (PSPTO_4098 or PSPTO_4097 or PSPTO_4685 or PSPTO_2991)
# rxn03247
# PSPTO_3517
# rxn10210
# PSPTO_1520
# rxn01476
# PSPTO_1301
# rxn00205
# ((PSPTO_1172 or PSPTO_1781 or PSPTO_1719) or (PSPTO_1719 or PSPTO_1781 or PSPTO_1172))
# rxn02576
# PSPTO_4026
# rxn03146
# PSPTO_4402
# rxn11650
# PSPTO_1710
# rxn03893
# PSPTO_5476
# rxn02789
# (PSPTO_2174 or PSPTO_2173 or (PSPTO_2174 and PSPTO_2173))
# rxn00988
# (Unknown and (PSPTO_4098 or PSPTO_4097 or PSPTO_4685 or PSPTO_2991))
# rxn01600
# PSPTO_4225
# rxn05455
# (PSPTO_3833 or PSPTO_5081)
# rxn00410
# (PSPTO_1552 or PSPTO_4155)
# rxn03063
# PSPTO_5282
# rxn01333
# PSPTO_2119
# rxn02925
# (PSPTO_5308 or PSPTO_0774)
# rxn10257
# PSPTO_4026
# rxn06394
# (PSPTO_3170 or PSPTO_3694 or PSPTO_3318)
# rxn12510
# PSPTO_0611
# rxn03933
# PSPTO_4408
# rxn07684
# PSPTO_3517
# rxn05342
# (PSPTO_4201 or PSPTO_4380 or PSPTO_3832 or PSPTO_3054 or PSPTO_2396)
# rxn00407
# PSPTO_4144
# rxn00333
# (PSPTO_3555 and Unknown)
# rxn05146
# ((PSPTO_2913 or PSPTO_4174) and (PSPTO_2915 or PSPTO_4172) and PSPTO_4171 and (PSPTO_4173 or PSPTO_2914))
# rxn05737
# (PSPTO_3466 or PSPTO_1795)
# rxn00414
# (PSPTO_4501 and PSPTO_4502)
# rxn09110
# (PSPTO_5536 or PSPTO_3022)
# rxn00529
# PSPTO_1508
# rxn03970
# PSPTO_1108
# rxn05594
# ((PSPTO_1788 or PSPTO_1791) and PSPTO_1796 and PSPTO_1797)
# rxn00159
# PSPTO_3924
# rxn05349
# ((PSPTO_4683 or PSPTO_3830) and PSPTO_1916)
# rxn00303
# (PSPTO_1694 or PSPTO_0073 or PSPTO_0856)
# rxn05512
# (PSPTO_1796 and (PSPTO_1791 or PSPTO_1788) and PSPTO_1797)
# rxn00799
# (PSPTO_4339 or (PSPTO_1731 or PSPTO_4461))
# rxn01977
# PSPTO_0959
# rxn11585
# PSPTO_2250
# rxn01073
# ((PSPTO_2107 or PSPTO_0660) or PSPTO_3461)
# rxn02405
# (PSPTO_3843 or (PSPTO_1539 or PSPTO_5541))
# rxn00011
# ((PSPTO_0982 and PSPTO_0981) or (PSPTO_3860 or PSPTO_5005 or PSPTO_3862))
# rxn02200
# (PSPTO_4496 or (PSPTO_1748 or PSPTO_1041))
# rxn01069
# PSPTO_1481
# rxn05528
# (PSPTO_0750 or PSPTO_5279 or PSPTO_1996 or PSPTO_2271)
# rxn00791
# PSPTO_0593
# rxn02883
# PSPTO_2944
# rxn03150
# PSPTO_1716
# rxn05108
# PSPTO_1440
# rxn00065
# (PSPTO_0230 or PSPTO_0230)
# rxn01827
# ((PSPTO_3553 or PSPTO_2346) or (PSPTO_2346 or PSPTO_3553))
# rxn00358
# PSPTO_2898
# rxn02321
# (PSPTO_1047 or PSPTO_1298)
# rxn01672
# PSPTO_4144
# rxn05312
# (PSPTO_4312 or PSPTO_3702)
# rxn08975
# PSPTO_0917
# rxn03378
# (PSPTO_2039 or PSPTO_1354 or PSPTO_1356 or PSPTO_1859)
# rxn00105
# ((PSPTO_1232 or PSPTO_3530 or PSPTO_1230) or PSPTO_4828)
# rxn03243
# (PSPTO_3164 or (PSPTO_0744 or PSPTO_2940 or PSPTO_3516))
# rxn03446
# PSPTO_1481
# rxn01302
# (PSPTO_1480 or PSPTO_1480)
# rxn00025
# PSPTO_4235
# rxn14359
# PSPTO_5179
# rxn00490
# PSPTO_1335
# rxn03880
# PSPTO_2944
# rxn00101
# ((PSPTO_4895 and PSPTO_4894 and (PSPTO_4891 or PSPTO_2411)) or ((PSPTO_2412 or PSPTO_4910) and (PSPTO_4890 or PSPTO_2408) and (PSPTO_4911 or PSPTO_2409) and (PSPTO_4909 or PSPTO_2413)) or PSPTO_5394)
# rxn02130
# PSPTO_1838
# rxn00223
# (PSPTO_3002 or PSPTO_0959)
# rxn00784
# PSPTO_0973
# rxn05029
# PSPTO_1708
# rxn00456
# PSPTO_5179
# rxn05393
# (PSPTO_4201 or PSPTO_2396 or PSPTO_3054 or PSPTO_3832 or PSPTO_4380)
# rxn01418
# PSPTO_2510
# rxn00328
# ((PSPTO_1302 and PSPTO_1302) or PSPTO_1302)
# rxn02285
# PSPTO_3842
# rxn02303
# PSPTO_0170
# rxn02889
# (PSPTO_2736 or (Unknown and PSPTO_2738))
# rxn05663
# PSPTO_1817
# rxn00559
# (PSPTO_1232 or PSPTO_1230 or PSPTO_3530 or PSPTO_4913)
# rxn01109
# (PSPTO_2492 or PSPTO_2492)
# rxn08848
# PSPTO_5299
# rxn07883
# PSPTO_3517
# rxn10194
# (PSPTO_0705 and Unknown)
# rxn00691
# (PSPTO_2454 or PSPTO_0456 or PSPTO_4314)
# rxn08840
# PSPTO_5299
# rxn03923
# PSPTO_2288
# rxn06577
# PSPTO_0949
# rxn00290
# (PSPTO_3456 or PSPTO_3455)
# rxn03907
# PSPTO_1556
# rxn01987
# PSPTO_2371
# rxn03538
# PSPTO_1717
# rxn09310
# (Unknown and PSPTO_0433 and Unknown and Unknown and Unknown and (PSPTO_3438 or PSPTO_0272))
# rxn02834
# (PSPTO_5154 and PSPTO_5153)
# rxn01213
# (Unknown and PSPTO_0699 and Unknown and Unknown)
# rxn06647
# PSPTO_1777
# rxn03860
# PSPTO_3517
# rxn05092
# PSPTO_2046
# rxn00459
# (PSPTO_1554 or PSPTO_4616)
# rxn02085
# PSPTO_5270
# rxn03932
# (PSPTO_3500 and PSPTO_3498)
# rxn12851
# (PSPTO_4536 or (PSPTO_4561 or PSPTO_4559 or PSPTO_4558 or PSPTO_4557 or PSPTO_2576 or PSPTO_3248))
# rxn00770
# PSPTO_1104
# rxn10334
# (PSPTO_4349 or PSPTO_0095)
# rxn05153
# (PSPTO_0309 and PSPTO_0311 and PSPTO_0310 and PSPTO_0308)
# rxn10945
# (PSPTO_0838 or PSPTO_5488 or PSPTO_1579)
# rxn08806
# PSPTO_5299
# rxn05436
# PSPTO_3721
# rxn05195
# Unknown
# rxn05209
# ((PSPTO_2517 or PSPTO_5519) or (PSPTO_4533 or PSPTO_5174))
# rxn06377
# PSPTO_1276
# rxn10234
# PSPTO_4955
# rxn10121
# (PSPTO_3262 or PSPTO_2302)
# rxn00312
# PSPTO_0518
# rxn06197
# PSPTO_1669
# rxn01208
# PSPTO_2175
# rxn10163
# (PSPTO_0893 or PSPTO_1720)
# rxn05618
# PSPTO_2499
# rxn10474
# (PSPTO_3701 or PSPTO_2295 or PSPTO_2064 or PSPTO_2798)
# rxn00260
# (PSPTO_2925 or PSPTO_5504)
# rxn03380
# PSPTO_2430
# rxn07454
# PSPTO_0103
# rxn00461
# PSPTO_4441
# rxn05613
# ((PSPTO_5187 or PSPTO_5260 or PSPTO_5216) and (PSPTO_5189 or PSPTO_5261) and Unknown)
# rxn06037
# PSPTO_3517
# rxn00817
# PSPTO_0885
# rxn00181
# PSPTO_0387
# rxn05247
# (PSPTO_4098 or PSPTO_4097 or PSPTO_2991 or PSPTO_4685)
# rxn02460
# PSPTO_3845
# rxn03136
# (PSPTO_3360 or PSPTO_3360)
# rxn00222
# (PSPTO_3170 or PSPTO_3694 or PSPTO_3318)
# rxn10229
# (PSPTO_0984 or PSPTO_3463)
# rxn01387
# PSPTO_3356
# rxn00818
# PSPTO_0885
# rxn11727
# PSPTO_1559
# rxn02693
# PSPTO_5476
# rxn02937
# (PSPTO_1700 or PSPTO_1700)
# rxn08810
# PSPTO_5299
# rxn03467
# (PSPTO_3318 or PSPTO_3694 or PSPTO_3170)
# rxn01652
# PSPTO_1699
# rxn05493
# PSPTO_4296
# rxn00350
# PSPTO_0787
# rxn03137
# (PSPTO_4866 and PSPTO_4866)
# rxn10343
# (PSPTO_5279 or PSPTO_0750 or PSPTO_2271)
# rxn05544
# (PSPTO_4536 or (PSPTO_3248 or PSPTO_2576 or PSPTO_4561 or PSPTO_4559 or PSPTO_4558 or PSPTO_4557))
# rxn01115
# PSPTO_3122
# rxn08818
# PSPTO_5299
# rxn05239
# (Unknown and PSPTO_2280)
# rxn08312
# (PSPTO_1539 or PSPTO_5541)
# rxn00952
# PSPTO_3810
# rxn01396
# (PSPTO_5521 or (PSPTO_2281 or PSPTO_0346))
# rxn00161
# PSPTO_5134
# rxn01961
# (PSPTO_2277 or PSPTO_3043)
# rxn01517
# PSPTO_0075
# rxn00371
# (PSPTO_0181 or PSPTO_5407)
# rxn06750
# PSPTO_0699
# rxn10226
# (PSPTO_3463 or PSPTO_0984)
# rxn09978
# (PSPTO_3318 or PSPTO_3694 or PSPTO_3170)
# rxn09211
# (PSPTO_3463 or PSPTO_0984)
# rxn01807
# (PSPTO_5521 or (PSPTO_2281 or PSPTO_0346))
# rxn05006
# (PSPTO_3344 or PSPTO_2300)
# rxn04706
# PSPTO_2944
# rxn12206
# (PSPTO_5084 and PSPTO_5083 and Unknown and Unknown and PSPTO_5087 and PSPTO_5085 and Unknown)
# rxn01299
# PSPTO_2373
# rxn01800
# (PSPTO_3733 or PSPTO_2453)
# rxn02107
# (PSPTO_4103 or PSPTO_2176)
# rxn08309
# (PSPTO_5541 or PSPTO_1539)
# rxn05379
# ((PSPTO_4683 or PSPTO_3830) and PSPTO_1916)
# rxn01512
# PSPTO_1430
# rxn08655
# (PSPTO_3555 and Unknown and PSPTO_3556)
# rxn03841
# PSPTO_3829
# rxn00866
# PSPTO_1508
# rxn04954
# PSPTO_5069
# rxn06865
# (PSPTO_0182 or PSPTO_3871)
# rxn03249
# ((PSPTO_3517 and Unknown) or PSPTO_3517)
# rxn04113
# PSPTO_0809
# rxn00676
# (PSPTO_3164 or (PSPTO_3516 or PSPTO_0744 or PSPTO_2940))
# rxn05551
# PSPTO_2026
# rxn06515
# PSPTO_1742
# rxn05909
# PSPTO_2430
# rxn05599
# (PSPTO_1797 and (PSPTO_1791 or PSPTO_1788) and PSPTO_1796)
# rxn01257
# (PSPTO_0592 or PSPTO_0592 or PSPTO_2282)
# rxn09272
# (PSPTO_2197 or (PSPTO_2196 and Unknown and Unknown and PSPTO_2195 and Unknown and Unknown) or (PSPTO_2197 and PSPTO_2198))
# rxn03845
# PSPTO_3675
# rxn00903
# PSPTO_1332
# rxn00980
# PSPTO_0567
# rxn08469
# (PSPTO_1795 or PSPTO_3466)
# rxn01216
# PSPTO_0083
# rxn02213
# PSPTO_4859
# rxn05441
# PSPTO_3721
# rxn03365
# (PSPTO_2176 or PSPTO_4103)
# rxn01429
# PSPTO_3991
# rxn00086
# (PSPTO_3112 or PSPTO_4254)
# rxn03871
# PSPTO_1559
# rxn04989
# PSPTO_1822
# rxn03879
# PSPTO_2944
# rxn05454
# (PSPTO_3833 or PSPTO_5081)
# rxn01127
# PSPTO_1509
# rxn01461
# PSPTO_2119
# rxn05537
# (PSPTO_4536 or (PSPTO_4561 or PSPTO_4557 or PSPTO_4559 or PSPTO_4558 or PSPTO_2576 or PSPTO_3248))
# rxn02569
# PSPTO_0793
# rxn04908
# (PSPTO_2697 or PSPTO_2182 or PSPTO_2957 or PSPTO_4285 or PSPTO_1337)
# rxn05226
# (Unknown and Unknown and PSPTO_0954 and Unknown and Unknown)
# rxn08548
# PSPTO_1520
# rxn00615
# (PSPTO_4168 or PSPTO_2403)
# rxn08468
# (PSPTO_3466 or PSPTO_1795)
# rxn06160
# PSPTO_1169
# rxn05445
# PSPTO_3721
# rxn07493
# PSPTO_0544
# rxn00569
# ((PSPTO_3262 or PSPTO_2302) or PSPTO_3263)
# rxn05341
# (PSPTO_4201 or PSPTO_2396 or PSPTO_3832 or PSPTO_3054 or PSPTO_4380)
# rxn00406
# PSPTO_3517
# rxn03393
# PSPTO_5241
# rxn05449
# PSPTO_3721
# rxn06805
# PSPTO_1742
# rxn03971
# PSPTO_1108
# rxn10206
# PSPTO_1520
# rxn00083
# (PSPTO_2106 or PSPTO_5464)
# rxn00291
# (PSPTO_1838 or PSPTO_1838)
# rxn00495
# (PSPTO_5275 or PSPTO_5274)
# rxn06870
# PSPTO_1112
# rxn10202
# PSPTO_1520
# rxn06735
# PSPTO_0699
# rxn06804
# PSPTO_1742
# rxn02483
# (PSPTO_2866 or PSPTO_4478 or PSPTO_2865 or PSPTO_2342)
# rxn03236
# PSPTO_1821
# rxn01265
# PSPTO_4921
# rxn00874
# (PSPTO_3164 or (PSPTO_2940 or PSPTO_0744 or PSPTO_3516) or PSPTO_0957)
# rxn00834
# PSPTO_1449
# rxn00782
# (PSPTO_2102 or (PSPTO_0257 or PSPTO_0300))
# rxn01187
# PSPTO_1670
# rxn02369
# PSPTO_2341
# rxn05189
# (PSPTO_0763 and PSPTO_0761)
# rxn00704
# ((PSPTO_0083 or PSPTO_3035) or (PSPTO_0836 or PSPTO_3590))
# rxn01459
# (PSPTO_3064 or PSPTO_0092 or PSPTO_1881 or PSPTO_0728 or PSPTO_0418 or PSPTO_2673)
# rxn05252
# (PSPTO_4097 or PSPTO_4098 or PSPTO_4685 or PSPTO_2991)
# rxn01671
# (PSPTO_3143 or PSPTO_0805)
# rxn02362
# PSPTO_1560
# rxn05627
# PSPTO_2304
# rxn01630
# (PSPTO_0517 or PSPTO_0517)
# rxn12642
# ((PSPTO_0280 or PSPTO_1533 or PSPTO_2362) or PSPTO_1271 or PSPTO_3788)
# rxn05313
# PSPTO_0118
# rxn10339
# (PSPTO_0095 or PSPTO_4349)
# rxn05620
# (PSPTO_1797 and (PSPTO_1788 or PSPTO_1791) and PSPTO_1796)
# rxn07673
# PSPTO_5597
# rxn01332
# ((PSPTO_2275 or PSPTO_3027) and Unknown and PSPTO_1772)
# rxn08433
# PSPTO_1559
# rxn02045
# PSPTO_4800
# rxn01530
# (PSPTO_2182 or PSPTO_2697 or PSPTO_1337 or PSPTO_2957 or PSPTO_4285)
# rxn03881
# PSPTO_2944
# rxn01499
# PSPTO_1508
# rxn00320
# PSPTO_3517
# rxn00785
# (PSPTO_0385 or PSPTO_2402 or PSPTO_2401)
# rxn00693
# PSPTO_2732
# rxn03909
# PSPTO_0698
# rxn10806
# (PSPTO_1325 or PSPTO_4648 or PSPTO_1327 or PSPTO_4647 or PSPTO_2195 or PSPTO_1328 or PSPTO_1326)
# rxn01101
# (PSPTO_3460 or PSPTO_3287 or PSPTO_3920 or PSPTO_5294 or PSPTO_0258)
# rxn03084
# (PSPTO_1459 and Unknown and PSPTO_1459)
# rxn02007
# (PSPTO_3499 or PSPTO_3018)
# rxn10233
# PSPTO_4955
# rxn06600
# (((PSPTO_0316 or PSPTO_1275) and (PSPTO_0317 or PSPTO_1277)) or PSPTO_1699)
# rxn00216
# PSPTO_1289
# rxn06728
# PSPTO_0699
# rxn02005
# (Unknown and PSPTO_0954 and Unknown and Unknown)
# rxn08808
# PSPTO_5299
# rxn00558
# PSPTO_0959
# rxn12635
# ((PSPTO_2362 or PSPTO_1533 or PSPTO_0280) or PSPTO_1271 or PSPTO_3788)
# rxn04726
# (PSPTO_2182 or PSPTO_2697 or PSPTO_1337 or PSPTO_4285 or PSPTO_2957)
# rxn00550
# (PSPTO_2277 or PSPTO_3043)
# rxn07841
# PSPTO_4496
# rxn00806
# PSPTO_1332
# rxn05328
# PSPTO_3721
# rxn05160
# ((PSPTO_2400 or PSPTO_2369 or PSPTO_1161) and Unknown and (PSPTO_2398 or PSPTO_2368) and PSPTO_2367)
# rxn02199
# PSPTO_5049
# rxn05024
# PSPTO_2742
# rxn01851
# ((PSPTO_0092 or PSPTO_3064 or PSPTO_2673 or PSPTO_0418 or PSPTO_0728 or PSPTO_1881) or (PSPTO_4103 or PSPTO_2176))
# rxn11834
# (PSPTO_2697 or PSPTO_2182 or PSPTO_2957 or PSPTO_4285 or PSPTO_1337)
# rxn05201
# PSPTO_4653
# rxn09449
# (PSPTO_4685 or PSPTO_2991 or PSPTO_4097 or PSPTO_4098)
# rxn03630
# PSPTO_5198
# rxn05323
# PSPTO_3721
# rxn03002
# PSPTO_0567
# rxn00314
# PSPTO_5047
# rxn05656
# (PSPTO_1797 and PSPTO_1796 and (PSPTO_1791 or PSPTO_1788))
# rxn05538
# (PSPTO_4536 or (PSPTO_4561 or PSPTO_4559 or PSPTO_4557 or PSPTO_4558 or PSPTO_3248 or PSPTO_2576))
# rxn05616
# (PSPTO_3701 or PSPTO_2064 or PSPTO_2295 or PSPTO_2798)
# rxn08805
# PSPTO_5299
# rxn01507
# (PSPTO_3043 or PSPTO_2277)
# rxn01790
# ((PSPTO_4394 or PSPTO_2276) or (PSPTO_2276 or PSPTO_4394))
# rxn05651
# (PSPTO_3593 or PSPTO_3234 or PSPTO_0168)
# rxn00077
# PSPTO_3793
# rxn01388
# (PSPTO_3752 or (PSPTO_2016 and PSPTO_3752))
# rxn02391
# PSPTO_4495
# rxn03638
# (PSPTO_5597 and PSPTO_5597)
# rxn05438
# PSPTO_3721
# rxn02897
# PSPTO_1715
# rxn05126
# (PSPTO_4103 or PSPTO_2176)
# rxn01406
# PSPTO_2055
# rxn01919
# PSPTO_2965
# rxn05249
# (PSPTO_4685 or PSPTO_2991 or PSPTO_4098 or PSPTO_4097)
# rxn07413
# PSPTO_3241
# rxn02277
# PSPTO_0498
# rxn10223
# (PSPTO_1539 or PSPTO_5541)
# rxn04658
# (PSPTO_4103 or PSPTO_2176)
# rxn02596
# PSPTO_0885
# rxn00991
# PSPTO_2742
# rxn10260
# (PSPTO_5536 or PSPTO_3022)
# rxn03915
# (PSPTO_4103 or PSPTO_2176)
# rxn03242
# ((PSPTO_3517 and Unknown) or PSPTO_3517)
# rxn00541
# (PSPTO_1841 or PSPTO_0410)
# rxn01368
# (PSPTO_3733 or PSPTO_2453)
# rxn00629
# PSPTO_2703
# rxn00134
# PSPTO_0923
# rxn01480
# (PSPTO_0783 or PSPTO_3517 or PSPTO_0783)
# rxn09199
# PSPTO_4955
# rxn05233
# (PSPTO_1661 or PSPTO_1671)
# rxn09109
# (PSPTO_3022 or PSPTO_5536)
# rxn00141
# (PSPTO_5068 or (PSPTO_1356 or PSPTO_1859 or PSPTO_1354 or PSPTO_2039))
# rxn02003
# ((PSPTO_1080 or PSPTO_0677) or (PSPTO_1080 or PSPTO_0677))
# rxn07056
# ((PSPTO_0323 or PSPTO_0256) or PSPTO_0517 or PSPTO_5394)
# rxn05375
# (PSPTO_1916 and (PSPTO_4683 or PSPTO_3830))
# rxn14294
# PSPTO_2043
# rxn01200
# (PSPTO_0385 or PSPTO_2402 or PSPTO_2401)
# rxn08558
# PSPTO_4170
# rxn01241
# PSPTO_2201
# rxn00130
# PSPTO_0189
# rxn11720
# PSPTO_1559
# rxn00859
# PSPTO_4438
# rxn00438
# PSPTO_0695
# rxn04744
# (PSPTO_2176 or PSPTO_4103)
# rxn00288
# (PSPTO_2195 or PSPTO_2196 or (PSPTO_2198 and PSPTO_2197 and Unknown))
# rxn02185
# (PSPTO_0981 and PSPTO_0982)
# rxn00763
# (PSPTO_2697 or PSPTO_2182 or PSPTO_2957 or PSPTO_4285 or PSPTO_1337)
# rxn08550
# PSPTO_1520
# rxn00819
# PSPTO_0885
# rxn05176
# (PSPTO_0308 or PSPTO_0311)
# rxn08811
# PSPTO_5299
# rxn02473
# (PSPTO_5338 or PSPTO_2430)
# rxn01275
# (PSPTO_3564 or PSPTO_3564)
# rxn10174
# (PSPTO_0890 or PSPTO_0886)
# rxn06060
# (PSPTO_3438 or PSPTO_0272)
# rxn08656
# (PSPTO_3555 and PSPTO_3556 and Unknown)
# rxn06690
# PSPTO_1547
# rxn01434
# PSPTO_4155
# rxn00912
# (PSPTO_0961 or PSPTO_4866)
# rxn05644
# ((PSPTO_2400 or PSPTO_1161 or PSPTO_2369) and PSPTO_2367 and Unknown and (PSPTO_2368 or PSPTO_2398))
# rxn12147
# PSPTO_3495
# rxn08819
# PSPTO_5299
# rxn02345
# (PSPTO_3517 or PSPTO_3517)
# rxn03849
# (PSPTO_0177 or PSPTO_1598)
# rxn03512
# (PSPTO_3035 or PSPTO_0083)
# rxn00122
# (PSPTO_0805 and PSPTO_0805)
# rxn09979
# (PSPTO_3318 or PSPTO_3170 or PSPTO_3694)
# rxn06076
# (PSPTO_1661 or PSPTO_1671)
# rxn00985
# PSPTO_1669
# rxn01011
# ((PSPTO_2434 or PSPTO_1215) or (PSPTO_1215 or PSPTO_2434) or (PSPTO_1215 or PSPTO_2434))
# rxn12849
# (PSPTO_4536 or (PSPTO_4559 or PSPTO_4561 or PSPTO_4557 or PSPTO_4558 or PSPTO_2576 or PSPTO_3248))
# rxn05301
# PSPTO_1817
# rxn08294
# PSPTO_4026
# rxn05179
# ((PSPTO_4915 or PSPTO_4112) or PSPTO_4919 or (PSPTO_4110 or PSPTO_4917) or (PSPTO_4916 or PSPTO_2990 or PSPTO_4111) or (PSPTO_2989 or PSPTO_4918 or PSPTO_4109))
# rxn10259
# (PSPTO_5536 or PSPTO_3022)
# rxn01602
# (PSPTO_1183 or PSPTO_0437)
# rxn07720
# PSPTO_5597
# rxn08094
# (PSPTO_2199 or PSPTO_2201 or PSPTO_2200 or PSPTO_2510)
# rxn00794
# (PSPTO_0323 or PSPTO_0256)
# rxn01887
# PSPTO_2949
# rxn08467
# (PSPTO_1795 or PSPTO_3466)
# rxn03061
# PSPTO_3752
# rxn02927
# PSPTO_1836
# rxn05433
# PSPTO_3721
# rxn04631
# PSPTO_2709
# rxn05344
# (((PSPTO_4683 or PSPTO_3830) and PSPTO_1916) or PSPTO_2210)
# rxn03241
# PSPTO_3517
# rxn01521
# (PSPTO_2277 or PSPTO_3043)
# rxn12636
# ((PSPTO_0280 or PSPTO_1533 or PSPTO_2362) or PSPTO_1271 or PSPTO_3788)
# rxn11759
# PSPTO_3811
# rxn07725
# PSPTO_2944
# rxn05414
# (PSPTO_4380 or PSPTO_3054 or PSPTO_3832 or PSPTO_2396 or PSPTO_4201)
# rxn00338
# PSPTO_4225
# rxn05384
# (PSPTO_1916 and (PSPTO_3830 or PSPTO_4683))
# rxn01975
# (PSPTO_1300 or PSPTO_3121)
# rxn00700
# PSPTO_3843
# rxn02373
# PSPTO_4829
# rxn03839
# (PSPTO_0517 or PSPTO_1441)
# rxn03094
# (PSPTO_0338 or PSPTO_4945 or PSPTO_5528)
# rxn06631
# PSPTO_0517
# rxn00085
# (PSPTO_5121 and (PSPTO_3415 or PSPTO_0687 or PSPTO_2095 or PSPTO_4359 or PSPTO_3479 or PSPTO_2253 or PSPTO_0710 or PSPTO_2585 or PSPTO_3038 or PSPTO_5644 or PSPTO_4835 or PSPTO_5114 or PSPTO_2361 or PSPTO_2226 or PSPTO_5123 or PSPTO_2274 or PSPTO_1721 or PSPTO_2693 or PSPTO_1176 or PSPTO_0333))
# rxn00119
# (PSPTO_1509 or PSPTO_0075)
# rxn02529
# PSPTO_1930
# rxn11749
# (PSPTO_3733 or PSPTO_2453)
# rxn03878
# PSPTO_2944
# rxn04453
# (PSPTO_4157 or PSPTO_5041)
# rxn08549
# PSPTO_1520
# rxn05468
# Unknown
# rxn09345
# PSPTO_1538
# rxn05447
# PSPTO_3721
# rxn01633
# PSPTO_1005
# rxn01466
# ((Unknown and Unknown and Unknown and PSPTO_0699) or PSPTO_0699)
# rxn05106
# PSPTO_2047
# rxn03409
# PSPTO_0359
# rxn09692
# PSPTO_5269
# rxn00974
# (PSPTO_3752 or (PSPTO_3752 and PSPTO_2016))
# rxn01948
# PSPTO_1508
# rxn02882
# PSPTO_2944
# rxn00744
# (PSPTO_2826 or (PSPTO_3188 or PSPTO_3189))
# rxn02008
# PSPTO_4410
# rxn05740
# PSPTO_5165
# rxn09203
# PSPTO_4955
# rxn03904
# PSPTO_4411
# rxn01225
# ((PSPTO_0765 or PSPTO_3663) or PSPTO_0757)
# rxn07842
# PSPTO_4496
# rxn01171
# (PSPTO_1298 or PSPTO_1047)
# rxn03931
# PSPTO_3495
# rxn02288
# PSPTO_5118
# rxn10199
# (PSPTO_0977 or PSPTO_5133)
# rxn00783
# (PSPTO_2178 or PSPTO_0542)
# rxn00409
# PSPTO_1430
# rxn01107
# (PSPTO_2470 or PSPTO_1052 or PSPTO_1345)
# rxn07885
# (PSPTO_4103 or PSPTO_2176)
# rxn05534
# (PSPTO_4536 or (PSPTO_4561 or PSPTO_4559 or PSPTO_4558 or PSPTO_4557 or PSPTO_3248 or PSPTO_2576))
# rxn01258
# PSPTO_2595
# rxn08842
# PSPTO_5299
# rxn05669
# PSPTO_2206
# rxn00778
# (PSPTO_3590 or PSPTO_0836)
# rxn03901
# PSPTO_3141
# rxn02832
# PSPTO_2289
# rxn05621
# ((PSPTO_1788 or PSPTO_1791) and PSPTO_1796 and PSPTO_1797)
# rxn10052
# PSPTO_1509
# rxn07672
# PSPTO_5597
# rxn04133
# Unknown
# rxn05540
# (PSPTO_4536 or (PSPTO_4561 or PSPTO_4557 or PSPTO_4559 or PSPTO_4558 or PSPTO_3248 or PSPTO_2576))
# rxn00193
# (PSPTO_1112 or PSPTO_0224)
# rxn14167
# PSPTO_5179
# rxn05326
# PSPTO_3721
# rxn06760
# (PSPTO_3318 or PSPTO_3694 or PSPTO_3170)
# rxn04840
# (PSPTO_1172 or PSPTO_1781 or PSPTO_1719)
# rxn05197
# (PSPTO_1871 or PSPTO_1129)
# rxn00653
# (PSPTO_3064 or PSPTO_0092 or PSPTO_1881 or PSPTO_0728 or PSPTO_0418 or PSPTO_2673)
# rxn05507
# PSPTO_3798
# rxn05155
# (PSPTO_3009 or PSPTO_5248 or PSPTO_2778)
# rxn00929
# PSPTO_5047
# rxn08800
# PSPTO_5299
# rxn11892
# PSPTO_1169
# rxn00256
# (PSPTO_2194 or PSPTO_1444)
# rxn03644
# PSPTO_3002
# rxn03507
# PSPTO_3668
# rxn03004
# (PSPTO_1699 or PSPTO_1699)
# rxn10232
# PSPTO_4955
# rxn00138
# PSPTO_4922
# rxn05536
# (PSPTO_4536 or (PSPTO_2576 or PSPTO_3248 or PSPTO_4561 or PSPTO_4559 or PSPTO_4557 or PSPTO_4558))
# rxn06729
# PSPTO_1546
# rxn00921
# PSPTO_4955
# rxn05168
# ((PSPTO_4112 or PSPTO_4915) or PSPTO_4919 or (PSPTO_4110 or PSPTO_4917) or (PSPTO_2990 or PSPTO_4111 or PSPTO_4916) or (PSPTO_4109 or PSPTO_4918 or PSPTO_2989))
# rxn02015
# (PSPTO_0338 or PSPTO_5528 or PSPTO_4945)
# rxn05546
# (PSPTO_4536 or (PSPTO_4561 or PSPTO_4559 or PSPTO_4557 or PSPTO_4558 or PSPTO_3248 or PSPTO_2576))
# rxn00347
# PSPTO_5499
# rxn05054
# PSPTO_1711
# rxn02167
# PSPTO_3517
# rxn05368
# (PSPTO_4201 or PSPTO_2396 or PSPTO_3832 or PSPTO_3054 or PSPTO_4380)
# rxn01858
# PSPTO_0757
# rxn01621
# PSPTO_1670
# rxn10770
# (PSPTO_0443 or (PSPTO_2182 or PSPTO_2697 or PSPTO_1337 or PSPTO_2957 or PSPTO_4285))
# rxn01364
# PSPTO_2568
# rxn00231
# (PSPTO_0517 or PSPTO_1441)
# rxn10161
# (PSPTO_1720 or PSPTO_0893)
# rxn05360
# (PSPTO_4201 or PSPTO_2396 or PSPTO_4380 or PSPTO_3832 or PSPTO_3054)
# rxn02297
# PSPTO_0495
# rxn05421
# ((PSPTO_3830 or PSPTO_4683) and PSPTO_1916)
# rxn04694
# PSPTO_2944
# rxn00897
# PSPTO_3278
# rxn01485
# PSPTO_4495
# rxn05206
# (PSPTO_1852 or PSPTO_0676)
# rxn03031
# (PSPTO_1528 or PSPTO_1528)
# rxn09207
# (PSPTO_0984 or PSPTO_3463)
# rxn09296
# (PSPTO_1688 or PSPTO_5243)
# rxn00239
# (PSPTO_0075 or PSPTO_0075)
# rxn00441
# (PSPTO_2199 or PSPTO_2510)
# rxn00302
# ((PSPTO_1182 or PSPTO_2035) or PSPTO_2578)
# rxn02465
# PSPTO_0604
# rxn02222
# (PSPTO_1441 or PSPTO_0517)
# rxn02093
# PSPTO_0885
# rxn03130
# PSPTO_3745
# rxn01791
# PSPTO_0960
# rxn00183
# PSPTO_5017
# rxn01148
# PSPTO_2177
# rxn00623
# (PSPTO_2730 and Unknown)
# rxn03333
# (PSPTO_2957 or PSPTO_4285 or PSPTO_1337 or PSPTO_2697 or PSPTO_2182)
# rxn11725
# PSPTO_1559
# rxn06526
# PSPTO_4858
# rxn05543
# (PSPTO_4536 or (PSPTO_4559 or PSPTO_4561 or PSPTO_4557 or PSPTO_4558 or PSPTO_2576 or PSPTO_3248))
# rxn11609
# PSPTO_0885
# rxn03465
# (PSPTO_3694 or PSPTO_3170 or PSPTO_3318)
# rxn01329
# PSPTO_0083
# rxn00950
# (PSPTO_4265 or PSPTO_0701)
# rxn00002
# ((PSPTO_1361 or PSPTO_4244) or ((PSPTO_2919 or PSPTO_5380 or PSPTO_2934) and (PSPTO_2920 or PSPTO_5380 or PSPTO_2935)))
# rxn02507
# PSPTO_0594
# rxn00542
# PSPTO_0973
# rxn01029
# PSPTO_5393
# rxn10341
# (PSPTO_4349 or PSPTO_0095)
# rxn05937
# (PSPTO_4642 or PSPTO_4024)
# rxn10220
# (PSPTO_1539 or PSPTO_5541)
# rxn05464
# PSPTO_3721
# rxn10261
# (PSPTO_5536 or PSPTO_3022)
# rxn01964
# ((PSPTO_0159 and PSPTO_0158) or PSPTO_5251)
# rxn08816
# PSPTO_5299
# rxn02341
# (PSPTO_0085 and PSPTO_0085)
# rxn06591
# PSPTO_1108
# rxn01519
# (PSPTO_0084 or PSPTO_3141)
# rxn01137
# PSPTO_0757
# rxn01014
# (PSPTO_2866 or PSPTO_4478 or PSPTO_2865 or PSPTO_2342)
# rxn10255
# PSPTO_4026
# rxn08797
# PSPTO_5299
# rxn01805
# PSPTO_2179
# rxn00127
# PSPTO_0598
# rxn06759
# PSPTO_0699
# rxn09108
# (PSPTO_5536 or PSPTO_3022)
# rxn00224
# PSPTO_1128
# rxn03323
# PSPTO_5393
# rxn01513
# PSPTO_3827
# rxn05372
# (PSPTO_3832 or PSPTO_3054 or PSPTO_4380 or PSPTO_2396 or PSPTO_4201)
# rxn06510
# (PSPTO_3164 or (PSPTO_3516 or PSPTO_2940 or PSPTO_0744))
# rxn02105
# (PSPTO_1361 or PSPTO_4244)
# rxn08307
# (PSPTO_1539 or PSPTO_5541)
# rxn05426
# (PSPTO_3054 or PSPTO_3832 or PSPTO_4380 or PSPTO_2396 or PSPTO_4201)
# rxn00209
# PSPTO_4116
# rxn01274
# PSPTO_3714
# rxn02474
# (PSPTO_0690 or PSPTO_0690)
# rxn02230
# PSPTO_0494
# rxn03246
# ((Unknown and PSPTO_3517) or PSPTO_3517)
# rxn04783
# PSPTO_1468
# rxn06517
# (PSPTO_0701 or PSPTO_4265)
# rxn02144
# (PSPTO_3138 or PSPTO_4089)
# rxn00604
# (PSPTO_3121 or PSPTO_1300)
# rxn08657
# (PSPTO_3555 and Unknown and PSPTO_3556)
# rxn12645
# ((PSPTO_0280 or PSPTO_2362 or PSPTO_1533) or PSPTO_1271 or PSPTO_3788)
# rxn05306
# (PSPTO_1817 and Unknown)
# rxn05605
# PSPTO_4063
# rxn01019
# PSPTO_4164
# rxn08849
# PSPTO_5299
# rxn09448
# (PSPTO_2991 or PSPTO_4685 or PSPTO_4097 or PSPTO_4098)
# rxn09208
# (PSPTO_0984 or PSPTO_3463)
# rxn05439
# PSPTO_3721
# rxn02406
# PSPTO_3705
# rxn05305
# (PSPTO_1221 or PSPTO_3452 or PSPTO_2504)
# rxn08295
# PSPTO_4026
# rxn05638
# (PSPTO_1579 or PSPTO_5488 or PSPTO_0838)
# rxn02914
# PSPTO_1746
# rxn01603
# (PSPTO_3814 and PSPTO_3814)
# rxn00055
# PSPTO_3902
# rxn00686
# (PSPTO_1183 or PSPTO_0437)
# rxn00905
# PSPTO_4866
# rxn05456
# (PSPTO_5081 or PSPTO_3833)
# rxn09112
# (PSPTO_5536 or PSPTO_3022)
# rxn05105
# PSPTO_2047
# rxn03194
# (PSPTO_0982 and PSPTO_0981)
# rxn06075
# (PSPTO_1661 or PSPTO_1671)
# rxn00689
# (PSPTO_3814 and PSPTO_3814)
# rxn08129
# PSPTO_3127
# rxn01286
# (PSPTO_0418 or PSPTO_0728 or PSPTO_1881 or PSPTO_2673 or PSPTO_3064 or PSPTO_0092)
# rxn05289
# (PSPTO_1178 or PSPTO_3906)
# rxn01973
# PSPTO_1523
# rxn05467
# Unknown
# rxn00117
# PSPTO_1430
# rxn01308
# PSPTO_1670
# rxn05343
# (((PSPTO_3830 or PSPTO_4683) and PSPTO_1916) or PSPTO_2210)
# rxn01520
# PSPTO_5282
# rxn05425
# (PSPTO_1916 and (PSPTO_4683 or PSPTO_3830))
# rxn03395
# PSPTO_1742
# rxn00330
# (PSPTO_0480 or PSPTO_3559)
# rxn05736
# (PSPTO_4685 or PSPTO_2991 or PSPTO_4097 or PSPTO_4098)
# rxn03445
# PSPTO_1746
# rxn01641
# PSPTO_0178
# rxn11663
# PSPTO_0552
# rxn01226
# PSPTO_2373
# rxn00493
# ((PSPTO_5339 or PSPTO_2163) or (PSPTO_4437 and Unknown) or PSPTO_2163)
# rxn08298
# PSPTO_4026
# rxn03442
# PSPTO_2944
# rxn00560
# PSPTO_4243
# rxn01834
# PSPTO_3106
# rxn00293
# (PSPTO_5597 and PSPTO_5597)
# rxn05383
# (PSPTO_3833 or PSPTO_5081)
# rxn10196
# (PSPTO_0705 and Unknown)
# rxn00839
# PSPTO_1430
# rxn03838
# PSPTO_0885
# rxn04732
# PSPTO_2944
# rxn10094
# Unknown
# rxn02304
# Unknown
# rxn00851
# Unknown
# rxn10265
# Unknown
# rxn10266
# Unknown
# rxn05390
# Unknown
# rxn00440
# Unknown
# rxn08713
# Unknown
# rxn05365
# Unknown
# rxn05402
# Unknown
# rxn10215
# Unknown
# rxn05148
# Unknown
# rxn12664
# Unknown
# rxn02831
# Unknown
# rxn05039
# Unknown
# rxn03164
# Unknown
# rxn12225
# Unknown
# rxn03919
# Unknown
# rxn03397
# Unknown
# rxn02774
# Unknown
# rxn08710
# Unknown
# rxn01117
# Unknown
# rxn09128
# Unknown
# rxn08619
# Unknown
# rxn05381
# Unknown
# rxn08620
# Unknown
# rxn12008
# Unknown
# rxn05361
# Unknown
# rxn05398
# Unknown
# rxn09436
# Unknown
# rxn03439
# Unknown
# rxn09163
# Unknown
# rxn02286
# Unknown
# rxn09225
# Unknown
# rxn03511
# Unknown
# rxn10626
# Unknown
# rxn03916
# Unknown
# rxn04139
# Unknown
# rxn00056
# Unknown
# rxn08333
# Unknown
# rxn05293
# Unknown
# rxn08583
# Unknown
# rxn08708
# Unknown
# rxn05373
# Unknown
# rxn10473
# Unknown
# rxn06848
# Unknown
# rxn05394
# Unknown
# rxn05386
# Unknown
# rxn05377
# Unknown
# rxn10214
# Unknown
# rxn05267
# Unknown
# rxn02056
# Unknown
# rxn08712
# Unknown
# rxn03918
# Unknown
# rxn13661
# Unknown
# rxn03917
# Unknown
# rxn05369
# Unknown
# rxn02269
# Unknown
# rxn08709
# Unknown
# rxn03182
# Unknown
# rxn05255
# Unknown
# rxn05406
# Unknown
# rxn12224
# Unknown
# o1" name
#
# _cpd0006
#
# _cpd0010
#
# _cpd0007
#
# _cpd0003
#
# _cpd1157
#
# _cpd0409
#
# _cpd0015
#
# _cpd1158
#
# _cpd1158
#
# _cpd0001
#
# _cpd1158
#
# _cpd0103
#
# _cpd0012
#
# _cpd0097
#
# _cpd0101
#
# _cpd0063
#
# _cpd0027
#
# _cpd0008
#
# _cpd0008
#
# _cpd0000
#
# _cpd1556
#
# _cpd1556
#
# _cpd0006
#
# _cpd0005
#
# _cpd0010
#
# _cpd0031
#
# _cpd0101
#
# _cpd0001
#
# _cpd1157
#
# _cpd0030
#
# _cpd0017
#
# _cpd0035
#
# _cpd0010
#
# _cpd1159
#
# _cpd0000
#
# _cpd0028
#
# _cpd0006
#
# _cpd0003
#
# _cpd1051
#
# _cpd0021
#
# _cpd0011
#
# _cpd1159
#
# _cpd0007
#
# _cpd0032
#
# _cpd1157
#
# _cpd0117
#
# _cpd0021
#
# _cpd1530
#
# _cpd1560
#
# _cpd0026
#
# _cpd0005
#
# _cpd0063
#
# _cpd0012
#
# _cpd1560
#
# _cpd0369
#
# _cpd0011
#
# _cpd0016
#
# _cpd0030
#
# _cpd1158
#
# _cpd0109
#
# _cpd0126
#
# _cpd0013
#
# _cpd0058
#
# _cpd0028
#
# _cpd0030
#
# _cpd0004
#
# _cpd0065
#
# _cpd0025
#
# _cpd0020
#
# _cpd0013
#
# _cpd0270
#
# _cpd0030
#
# _cpd0124
#
# _cpd0104
#
# _cpd0002
#
# _cpd0304
#
# _cpd1159
#
# _cpd0006
#
# _cpd1560
#
# _cpd0004
#
# _cpd0384
#
# _cpd0003
#
# _cpd0014
#
# _cpd0191
#
# _cpd0002
#
# _cpd0053
#
# _cpd1158
#
# _cpd0016
#
# _cpd0039
#
# _cpd1158
#
# _cpd0002
#
# _cpd0372
#
# _cpd0020
#
# _cpd1157
#
# _cpd0079
#
# _cpd0010
#
# _cpd0022
#
# _cpd0987
#
# _cpd1158
#
# _cpd0026
#
# _cpd0132
#
# _cpd1560
#
# _cpd0006
#
# _cpd0000
#
# _cpd0009
#
# _cpd1159
#
# _cpd0015
#
# _cpd0802
#
# _cpd1158
#
# _cpd0009
#
# _cpd0409
#
# _cpd0005
#
# _cpd1159
#
# _cpd1158
#
# _cpd0108
#
# _cpd1158
#
# _cpd0006
#
# _cpd0013
#
# _cpd0003
#
# _cpd0001
#
# _cpd1141
#
# _cpd0002
#
# _cpd1160
#
# _cpd0009
#
# _cpd0039

# %%
#generate a dictionary of reactions that are in draft but not in the current state of the model, this will be used for comparison and further curation
pst_8 = cobra.io.read_sbml_model('../results/reconstructions/pstv8.xml')
missing_from_v8 = {}
for rxn, gene in draft_gprs.items():
    rxn = rxn + "_c"
    try:
        pst_8.reactions.get_by_id(rxn)
    except:
        missing_from_v8[rxn] = gene

# %%
with open('../data/missing_reactions_draft_v_v8.csv', 'w') as f:
    for key in missing_from_v8.keys():
        f.write("%s,%s\n"%(key,missing_from_v8[key]))

# %% [markdown]
# The final output is a list of reactions that do not appear in the v8 of iPto yet have GPRs in the draft reconstruction. These are manually checked by looking at the GPR and seeing if the ascribed gene fufills the function or the reaction. If yes, it was given a 1, if no, or there is otherwise no substantiated annnotation, it was given a 0. All 1s were integrated back into the model, while all 0s were left out in the following cell.

# %%
import pandas as pd
missing_rxns = pd.read_excel("../data/missing_reactions_draft_v_v8.xlsx")
gprs_to_add_to_v8 = {}
for row in missing_rxns.itertuples():
    if row.evidence == 1:
        gprs_to_add_to_v8[row.id] = row.gpr

# %%
from medusa.test import load_universal_modelseed
universal = load_universal_modelseed()
mod_copy = pst_8.copy()

# %%
for key,value in gprs_to_add_to_v8.items():
    try:
        rxn_to_add = universal.reactions.get_by_id(key).copy()
        rxn_to_add.gene_reaction_rule = value
        print ("I will now add " + key + " to the model.")
        mod_copy.add_reactions([rxn_to_add])
    except:
        print(key + " did not appear in the universal model. I did not add " + key + " to the model.")
# Out:
# I will now add rxn06600_c to the model.
# I will now add rxn00512_c to the model.
# I will now add rxn05343_c to the model.
# I will now add rxn05344_c to the model.
# I will now add rxn05347_c to the model.
# I will now add rxn12634_c to the model.
# I will now add rxn12636_c to the model.
# I will now add rxn12639_c to the model.
# I will now add rxn12642_c to the model.
# I will now add rxn12847_c to the model.
# I will now add rxn12633_c to the model.
# I will now add rxn12645_c to the model.
# I will now add rxn12646_c to the model.
# I will now add rxn12846_c to the model.
# I will now add rxn01225_c to the model.
# I will now add rxn05549_c to the model.
# I will now add rxn00205_c to the model.
# I will now add rxn00302_c to the model.
# I will now add rxn00641_c to the model.
# I will now add rxn12637_c to the model.
# I will now add rxn12640_c to the model.
# I will now add rxn12643_c to the model.
# I will now add rxn12845_c to the model.
# I will now add rxn00758_c to the model.
# I will now add rxn01073_c to the model.
# I will now add rxn01643_c to the model.
# I will now add rxn00543_c to the model.
# I will now add rxn00568_c to the model.
# I will now add rxn00650_c to the model.
# I will now add rxn12635_c to the model.
# I will now add rxn12638_c to the model.
# I will now add rxn12644_c to the model.
# I will now add rxn12844_c to the model.
# I will now add rxn05644_c to the model.
# I will now add rxn05160_c to the model.
# I will now add rxn00324_c to the model.
# I will now add rxn01011_c to the model.
# I will now add rxn01013_c to the model.
# I will now add rxn00569_c to the model.
# I will now add rxn05145_c to the model.
# I will now add rxn03242_c to the model.
# I will now add rxn03244_c to the model.
# I will now add rxn03249_c to the model.
# I will now add rxn00999_c to the model.
# I will now add rxn05421_c to the model.
# rxn05460_c did not appear in the universal model. I did not add rxn05460_c to the model.
# I will now add rxn01465_c to the model.
# rxn05379_c did not appear in the universal model. I did not add rxn05379_c to the model.
# rxn05404_c did not appear in the universal model. I did not add rxn05404_c to the model.
# I will now add rxn03246_c to the model.
# rxn04750_c did not appear in the universal model. I did not add rxn04750_c to the model.
# I will now add rxn06777_c to the model.
# I will now add rxn01509_c to the model.
# I will now add rxn01519_c to the model.
# I will now add rxn05734_c to the model.
# I will now add rxn05735_c to the model.
# I will now add rxn10335_c to the model.
# I will now add rxn10339_c to the model.
# I will now add rxn10340_c to the model.
# I will now add rxn10342_c to the model.
# I will now add rxn03849_c to the model.
# I will now add rxn00634_c to the model.
# I will now add rxn01286_c to the model.
# I will now add rxn10770_c to the model.
# I will now add rxn00920_c to the model.
# I will now add rxn00231_c to the model.
# I will now add rxn02275_c to the model.
# I will now add rxn00881_c to the model.
# I will now add rxn00883_c to the model.
# I will now add rxn02737_c to the model.
# I will now add rxn05189_c to the model.
# I will now add rxn01480_c to the model.
# I will now add rxn05170_c to the model.
# I will now add rxn10174_c to the model.
# I will now add rxn05501_c to the model.
# I will now add rxn05647_c to the model.
# I will now add rxn05569_c to the model.
# I will now add rxn00711_c to the model.
# I will now add rxn01544_c to the model.
# I will now add rxn04840_c to the model.
# I will now add rxn00686_c to the model.
# I will now add rxn01602_c to the model.
# I will now add rxn05305_c to the model.
# I will now add rxn00559_c to the model.
# I will now add rxn01171_c to the model.
# I will now add rxn01975_c to the model.
# I will now add rxn11838_c to the model.
# I will now add rxn00882_c to the model.
# I will now add rxn03869_c to the model.
# I will now add rxn01301_c to the model.
# I will now add rxn03031_c to the model.
# I will now add rxn08307_c to the model.
# I will now add rxn08312_c to the model.
# I will now add rxn10223_c to the model.
# I will now add rxn10224_c to the model.
# I will now add rxn00410_c to the model.
# I will now add rxn03848_c to the model.
# I will now add rxn10116_c to the model.
# I will now add rxn09296_c to the model.
# I will now add rxn04841_c to the model.
# I will now add rxn10161_c to the model.
# I will now add rxn10162_c to the model.
# I will now add rxn05306_c to the model.
# I will now add rxn05197_c to the model.
# rxn05384_c did not appear in the universal model. I did not add rxn05384_c to the model.
# rxn05409_c did not appear in the universal model. I did not add rxn05409_c to the model.
# rxn05359_c did not appear in the universal model. I did not add rxn05359_c to the model.
# I will now add rxn05375_c to the model.
# I will now add rxn05425_c to the model.
# rxn05429_c did not appear in the universal model. I did not add rxn05429_c to the model.
# I will now add rxn00782_c to the model.
# I will now add rxn02789_c to the model.
# I will now add rxn02811_c to the model.
# I will now add rxn03062_c to the model.
# I will now add rxn00532_c to the model.
# I will now add rxn04737_c to the model.
# I will now add rxn04744_c to the model.
# I will now add rxn05127_c to the model.
# I will now add rxn04726_c to the model.
# I will now add rxn12191_c to the model.
# I will now add rxn00441_c to the model.
# I will now add rxn02376_c to the model.
# I will now add rxn00611_c to the model.
# I will now add rxn01670_c to the model.
# I will now add rxn05256_c to the model.
# I will now add rxn01300_c to the model.
# I will now add rxn05338_c to the model.
# I will now add rxn00691_c to the model.
# I will now add rxn01107_c to the model.
# I will now add rxn01108_c to the model.
# I will now add rxn01109_c to the model.
# I will now add rxn04908_c to the model.
# I will now add rxn11809_c to the model.
# I will now add rxn11834_c to the model.
# I will now add rxn14054_c to the model.
# I will now add rxn02483_c to the model.
# I will now add rxn02339_c to the model.
# I will now add rxn03333_c to the model.
# I will now add rxn04736_c to the model.
# I will now add rxn14089_c to the model.
# I will now add rxn00223_c to the model.
# I will now add rxn02400_c to the model.
# I will now add rxn02853_c to the model.
# I will now add rxn00653_c to the model.
# I will now add rxn01459_c to the model.
# I will now add rxn00604_c to the model.
# I will now add rxn02144_c to the model.
# I will now add rxn06510_c to the model.
# I will now add rxn10121_c to the model.
# I will now add rxn09979_c to the model.
# I will now add rxn09978_c to the model.
# I will now add rxn05737_c to the model.
# I will now add rxn08468_c to the model.
# I will now add rxn08471_c to the model.
# I will now add rxn10067_c to the model.
# I will now add rxn02007_c to the model.
# I will now add rxn03932_c to the model.
# I will now add rxn08656_c to the model.
# I will now add rxn08655_c to the model.
# I will now add rxn08657_c to the model.
# I will now add rxn00333_c to the model.
# I will now add rxn05651_c to the model.
# I will now add rxn05616_c to the model.
# I will now add rxn03433_c to the model.
# I will now add rxn00689_c to the model.
# I will now add rxn01210_c to the model.
# I will now add rxn04658_c to the model.
# I will now add rxn04723_c to the model.
# I will now add rxn04727_c to the model.
# I will now add rxn05126_c to the model.
# I will now add rxn07875_c to the model.
# I will now add rxn07885_c to the model.
# I will now add rxn10334_c to the model.
# I will now add rxn10341_c to the model.
# I will now add rxn09240_c to the model.
# I will now add rxn00379_c to the model.
# I will now add rxn00863_c to the model.
# I will now add rxn02159_c to the model.
# I will now add rxn02200_c to the model.
# I will now add rxn00495_c to the model.
# I will now add rxn02314_c to the model.
# I will now add rxn05239_c to the model.
# I will now add rxn09562_c to the model.
# I will now add rxn01216_c to the model.
# I will now add rxn00519_c to the model.
# I will now add rxn12512_c to the model.
# I will now add rxn00756_c to the model.
# I will now add rxn02444_c to the model.
# I will now add rxn01345_c to the model.
# I will now add rxn01868_c to the model.
# I will now add rxn00312_c to the model.
# I will now add rxn01416_c to the model.
# I will now add rxn00980_c to the model.
# I will now add rxn03002_c to the model.
# I will now add rxn00438_c to the model.
# I will now add rxn01137_c to the model.
# I will now add rxn01858_c to the model.
# I will now add rxn05514_c to the model.
# I will now add rxn02792_c to the model.
# I will now add rxn02569_c to the model.
# I will now add rxn04113_c to the model.
# I will now add rxn04996_c to the model.
# I will now add rxn08971_c to the model.
# I will now add rxn08975_c to the model.
# I will now add rxn08976_c to the model.
# I will now add rxn02262_c to the model.
# I will now add rxn00904_c to the model.
# I will now add rxn00784_c to the model.
# I will now add rxn00292_c to the model.
# I will now add rxn02975_c to the model.
# I will now add rxn00216_c to the model.
# I will now add rxn01476_c to the model.
# I will now add rxn00490_c to the model.
# I will now add rxn02412_c to the model.
# I will now add rxn00515_c to the model.
# I will now add rxn01673_c to the model.
# I will now add rxn01069_c to the model.
# I will now add rxn03446_c to the model.
# I will now add rxn10052_c to the model.
# I will now add rxn08546_c to the model.
# I will now add rxn08547_c to the model.
# rxn08548_c did not appear in the universal model. I did not add rxn08548_c to the model.
# rxn08549_c did not appear in the universal model. I did not add rxn08549_c to the model.
# rxn08550_c did not appear in the universal model. I did not add rxn08550_c to the model.
# rxn08552_c did not appear in the universal model. I did not add rxn08552_c to the model.
# I will now add rxn10202_c to the model.
# I will now add rxn10203_c to the model.
# I will now add rxn10207_c to the model.
# I will now add rxn10208_c to the model.
# I will now add rxn10210_c to the model.
# I will now add rxn04278_c to the model.
# I will now add rxn08433_c to the model.
# I will now add rxn08438_c to the model.
# I will now add rxn11719_c to the model.
# I will now add rxn11720_c to the model.
# I will now add rxn11721_c to the model.
# I will now add rxn11722_c to the model.
# I will now add rxn11723_c to the model.
# I will now add rxn11724_c to the model.
# I will now add rxn11725_c to the model.
# I will now add rxn11726_c to the model.
# I will now add rxn11727_c to the model.
# I will now add rxn11801_c to the model.
# I will now add rxn00717_c to the model.
# I will now add rxn01025_c to the model.
# I will now add rxn01308_c to the model.
# I will now add rxn01621_c to the model.
# I will now add rxn06804_c to the model.
# I will now add rxn06805_c to the model.
# I will now add rxn00707_c to the model.
# I will now add rxn05301_c to the model.
# I will now add rxn05663_c to the model.
# I will now add rxn01315_c to the model.
# I will now add rxn04989_c to the model.
# I will now add rxn05682_c to the model.
# I will now add rxn09657_c to the model.
# I will now add rxn02529_c to the model.
# I will now add rxn06937_c to the model.
# I will now add rxn00735_c to the model.
# I will now add rxn01208_c to the model.
# I will now add rxn01872_c to the model.
# I will now add rxn05669_c to the model.
# I will now add rxn00679_c to the model.
# I will now add rxn05625_c to the model.
# I will now add rxn05627_c to the model.
# I will now add rxn01987_c to the model.
# I will now add rxn04043_c to the model.
# I will now add rxn01545_c to the model.
# I will now add rxn00508_c to the model.
# I will now add rxn05024_c to the model.
# I will now add rxn00358_c to the model.
# I will now add rxn03878_c to the model.
# I will now add rxn03879_c to the model.
# I will now add rxn03880_c to the model.
# I will now add rxn03881_c to the model.
# I will now add rxn04237_c to the model.
# I will now add rxn04694_c to the model.
# I will now add rxn04706_c to the model.
# I will now add rxn04715_c to the model.
# I will now add rxn07574_c to the model.
# rxn07578_c did not appear in the universal model. I did not add rxn07578_c to the model.
# I will now add rxn07725_c to the model.
# I will now add rxn07741_c to the model.
# I will now add rxn00968_c to the model.
# I will now add rxn01834_c to the model.
# I will now add rxn11040_c to the model.
# I will now add rxn08126_c to the model.
# I will now add rxn08127_c to the model.
# I will now add rxn08128_c to the model.
# I will now add rxn08129_c to the model.
# I will now add rxn00780_c to the model.
# I will now add rxn00938_c to the model.
# I will now add rxn00199_c to the model.
# I will now add rxn03931_c to the model.
# I will now add rxn12147_c to the model.
# I will now add rxn12146_c to the model.
# I will now add rxn03240_c to the model.
# I will now add rxn03241_c to the model.
# I will now add rxn03247_c to the model.
# I will now add rxn03287_c to the model.
# I will now add rxn03289_c to the model.
# I will now add rxn03860_c to the model.
# I will now add rxn06037_c to the model.
# I will now add rxn07680_c to the model.
# I will now add rxn07684_c to the model.
# I will now add rxn07688_c to the model.
# I will now add rxn07883_c to the model.
# I will now add rxn02406_c to the model.
# I will now add rxn05049_c to the model.
# I will now add rxn01274_c to the model.
# rxn05322_c did not appear in the universal model. I did not add rxn05322_c to the model.
# rxn05323_c did not appear in the universal model. I did not add rxn05323_c to the model.
# I will now add rxn05325_c to the model.
# rxn05326_c did not appear in the universal model. I did not add rxn05326_c to the model.
# rxn05327_c did not appear in the universal model. I did not add rxn05327_c to the model.
# I will now add rxn05328_c to the model.
# rxn05438_c did not appear in the universal model. I did not add rxn05438_c to the model.
# rxn05443_c did not appear in the universal model. I did not add rxn05443_c to the model.
# I will now add rxn05445_c to the model.
# I will now add rxn05446_c to the model.
# I will now add rxn05447_c to the model.
# I will now add rxn05448_c to the model.
# rxn05449_c did not appear in the universal model. I did not add rxn05449_c to the model.
# rxn05464_c did not appear in the universal model. I did not add rxn05464_c to the model.
# I will now add rxn07579_c to the model.
# I will now add rxn03061_c to the model.
# I will now add rxn01828_c to the model.
# I will now add rxn10060_c to the model.
# I will now add rxn05506_c to the model.
# I will now add rxn05507_c to the model.
# I will now add rxn06078_c to the model.
# I will now add rxn11759_c to the model.
# I will now add rxn01513_c to the model.
# I will now add rxn00700_c to the model.
# I will now add rxn05733_c to the model.
# I will now add rxn00407_c to the model.
# I will now add rxn00616_c to the model.
# I will now add rxn08557_c to the model.
# I will now add rxn08558_c to the model.
# I will now add rxn11944_c to the model.
# I will now add rxn04070_c to the model.
# I will now add rxn00560_c to the model.
# I will now add rxn05493_c to the model.
# I will now add rxn07219_c to the model.
# I will now add rxn03933_c to the model.
# I will now add rxn05201_c to the model.
# I will now add rxn03108_c to the model.
# I will now add rxn02961_c to the model.
# I will now add rxn00775_c to the model.
# I will now add rxn00314_c to the model.
# I will now add rxn03437_c to the model.
# I will now add rxn02312_c to the model.
# I will now add rxn00456_c to the model.
# I will now add rxn03630_c to the model.
# I will now add rxn01653_c to the model.
# I will now add rxn05578_c to the model.
# I will now add rxn03046_c to the model.
# I will now add rxn01520_c to the model.
# I will now add rxn03063_c to the model.
# I will now add rxn03035_c to the model.
# I will now add rxn07230_c to the model.
# I will now add rxn08647_c to the model.

# %%
print (str(len(mod_copy.genes)) + " genes are in the updated model, while " + str(len(pst_8.genes)) + " are in the older version of the model.")
# Out:
# 1549 genes are in the updated model, while 1208 are in the older version of the model.

# %%
import csv

#this is the chuck of code that should be used for exporting the model as a csv file
filevar = 'PSTv9'
filepath = "../results/reconstructions/"
filename = filepath+filevar+".csv"
with open(filename, 'w', newline='') as csvfile:
    csvfile = csv.writer(csvfile, delimiter=',')
    for rxn in mod_copy.reactions:
        csvfile.writerow([rxn.id, rxn.name, rxn.reaction, rxn.gene_reaction_rule,rxn.lower_bound, rxn.upper_bound])
