# %% [markdown]
# This is the whole gene_essentiality process as a script. Each of the files generated will serve a specific function and for keeping track of the different steps. Different cells in the notebook will denote some sort of manual operation that needs to be fufiled, which will be present in the comments.

# %%
import cobra
from cobra import Metabolite, Gene, Reaction
from cobra.flux_analysis import single_gene_deletion
import pandas as pd
from medusa.test import load_universal_modelseed
import medusa
from pickle import load
from medusa.flux_analysis import deletion
import re

# %%
import cobra
from cobra import Metabolite, Gene, Reaction
from cobra.flux_analysis import single_gene_deletion
import pandas as pd
from medusa.test import load_universal_modelseed
import medusa
from pickle import load
from medusa.flux_analysis import deletion
import re

#load ensebmle of choice
with open("../results/ensembles/pto_ensemble_500_genes_added_2.pickle", 'rb') as infile:
    ensemble = load(infile)
    
#set media conditions for each ensemble
#this will dictact what genes are essential for each media condition
#complete media has all of the exchange reactions open
complete = {}
for reaction in ensemble.base_model.reactions:
    if "EX_" in reaction.id:
        complete[reaction.id] = 1000

        
#for the other medias, use the base biolog salts (minus heme) and add the media types needed
from medusa.test import load_biolog_plata
biolog_base_composition, biolog_base_dict, biolog_thresholded = load_biolog_plata()
biolog_base_composition = biolog_base_composition.drop(18)

gluc_mm = {}

for x in biolog_base_composition.ID:
    gluc_mm['EX_' + x] = 1000 
gluc_mm['EX_cpd00027_e'] = 10

glut_mm = {}

for x in biolog_base_composition.ID:
    glut_mm['EX_' + x] = 1000
glut_mm['EX_cpd00053_e'] = 10

#load in the anderson metabolites
anderson_df = pd.read_csv("../data/metabolite_ids_Anderson2014.csv")
anderson_media_list = []
met_ids = [met for met in anderson_df.met_id]
for met in met_ids:
    met="EX_" + str(met) + "_e"
    anderson_media_list.append(met)
    
    
anderson = {}
for x in biolog_base_composition.ID:
    anderson['EX_' + x] = 1000 
for y in anderson_media_list:
    if y in ensemble.base_model.reactions:
        anderson[y] = 1000
        #print (y + " is IN the model")
    else:
        pass

    
#the model list is an important feature that will allow for the iteration over the ensemble members within an ensebmle and perform gene deletions on each one

# %%
model_list = []
for model in ensemble.members:
    model_list.append(model.id)

#set the media of choice
ensemble.base_model.medium = complete

#perform the deletions, this may take a few minutes
deletion_results = {}
with ensemble.base_model:
    for model in model_list:
        print('performing deletions for ' + model)
        ensemble.set_state(model)
        deletion_result = single_gene_deletion(ensemble.base_model)
        deletion_results[model] = deletion_result

#each member will have its own full set of deletions on a sheet within this file
with pd.ExcelWriter('../results/gene_essentiality/ensemble_essentialiity/500complete_media_ensemble_deletions.xlsx') as writer:  # doctest: +SKIP
    for key, value in deletion_results.items():
        value.to_excel(writer, sheet_name=key)
        
#the file must now be converted into one sheet for ease of access, this will take a long time
# Out:
# EX_cpd11493_c does not seem to be an an exchange reaction. Applying bounds anyway.
# EX_cpd11416_c does not seem to be an an exchange reaction. Applying bounds anyway.
# performing deletions for PST_gapfilled_0
# performing deletions for PST_gapfilled_1
# performing deletions for PST_gapfilled_2
# performing deletions for PST_gapfilled_3
# performing deletions for PST_gapfilled_4
# performing deletions for PST_gapfilled_5
# performing deletions for PST_gapfilled_6
# performing deletions for PST_gapfilled_7
# performing deletions for PST_gapfilled_8
# performing deletions for PST_gapfilled_9
# performing deletions for PST_gapfilled_10
# performing deletions for PST_gapfilled_11
# performing deletions for PST_gapfilled_12
# performing deletions for PST_gapfilled_13
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ...

# %%
#set the media of choice
ensemble.base_model.medium = gluc_mm

#perform the deletions, this may take a few minutes
deletion_results = {}
with ensemble.base_model:
    for model in model_list:
        print('performing deletions for ' + model)
        ensemble.set_state(model)
        deletion_result = single_gene_deletion(ensemble.base_model)
        deletion_results[model] = deletion_result

#each member will have its own full set of deletions on a sheet within this file
with pd.ExcelWriter('../results/gene_essentiality/ensemble_essentialiity/500gluc_media_ensemble_deletions.xlsx') as writer:  # doctest: +SKIP
    for key, value in deletion_results.items():
        value.to_excel(writer, sheet_name=key)
# Out:
# performing deletions for PST_gapfilled_0
# performing deletions for PST_gapfilled_1
# performing deletions for PST_gapfilled_2
# performing deletions for PST_gapfilled_3
# performing deletions for PST_gapfilled_4
# performing deletions for PST_gapfilled_5
# performing deletions for PST_gapfilled_6
# performing deletions for PST_gapfilled_7
# performing deletions for PST_gapfilled_8
# performing deletions for PST_gapfilled_9
# performing deletions for PST_gapfilled_10
# performing deletions for PST_gapfilled_11
# performing deletions for PST_gapfilled_12
# performing deletions for PST_gapfilled_13
# performing deletions for PST_gapfilled_14
# performing deletions for PST_gapfilled_15
# performing deletions for PST_gapfilled_16
# performing deletions for PST_gapfilled_17
# performing deletions for PST_gapfilled_18
# performing deletions for PST_gapfilled_19
# performing deletions for PST_gapfilled_20
# performing deletions for PST_gapfilled_21
# ...

# %%
#set the media of choice
ensemble.base_model.medium = glut_mm

#perform the deletions, this may take a few minutes
deletion_results = {}
with ensemble.base_model:
    for model in model_list:
        print('performing deletions for ' + model)
        ensemble.set_state(model)
        deletion_result = single_gene_deletion(ensemble.base_model)
        deletion_results[model] = deletion_result

#each member will have its own full set of deletions on a sheet within this file
with pd.ExcelWriter('../results/gene_essentiality/ensemble_essentialiity/500glut_media_ensemble_deletions.xlsx') as writer:  # doctest: +SKIP
    for key, value in deletion_results.items():
        value.to_excel(writer, sheet_name=key)
# Out:
# performing deletions for PST_gapfilled_0
# performing deletions for PST_gapfilled_1
# performing deletions for PST_gapfilled_2
# performing deletions for PST_gapfilled_3
# performing deletions for PST_gapfilled_4
# performing deletions for PST_gapfilled_5
# performing deletions for PST_gapfilled_6
# performing deletions for PST_gapfilled_7
# performing deletions for PST_gapfilled_8
# performing deletions for PST_gapfilled_9
# performing deletions for PST_gapfilled_10
# performing deletions for PST_gapfilled_11
# performing deletions for PST_gapfilled_12
# performing deletions for PST_gapfilled_13
# performing deletions for PST_gapfilled_14
# performing deletions for PST_gapfilled_15
# performing deletions for PST_gapfilled_16
# performing deletions for PST_gapfilled_17
# performing deletions for PST_gapfilled_18
# performing deletions for PST_gapfilled_19
# performing deletions for PST_gapfilled_20
# performing deletions for PST_gapfilled_21
# ...

# %%
#set the media of choice
ensemble.base_model.medium = anderson

#perform the deletions, this may take a few minutes
deletion_results = {}
with ensemble.base_model:
    for model in model_list:
        print('performing deletions for ' + model)
        ensemble.set_state(model)
        deletion_result = single_gene_deletion(ensemble.base_model)
        deletion_results[model] = deletion_result

#each member will have its own full set of deletions on a sheet within this file
with pd.ExcelWriter('../results/gene_essentiality/ensemble_essentialiity/500anderson_media_ensemble_deletions.xlsx') as writer:  # doctest: +SKIP
    for key, value in deletion_results.items():
        value.to_excel(writer, sheet_name=key)
# Out:
# performing deletions for PST_gapfilled_0
# performing deletions for PST_gapfilled_1
# performing deletions for PST_gapfilled_2
# performing deletions for PST_gapfilled_3
# performing deletions for PST_gapfilled_4
# performing deletions for PST_gapfilled_5
# performing deletions for PST_gapfilled_6
# performing deletions for PST_gapfilled_7
# performing deletions for PST_gapfilled_8
# performing deletions for PST_gapfilled_9
# performing deletions for PST_gapfilled_10
# performing deletions for PST_gapfilled_11
# performing deletions for PST_gapfilled_12
# performing deletions for PST_gapfilled_13
# performing deletions for PST_gapfilled_14
# performing deletions for PST_gapfilled_15
# performing deletions for PST_gapfilled_16
# performing deletions for PST_gapfilled_17
# performing deletions for PST_gapfilled_18
# performing deletions for PST_gapfilled_19
# performing deletions for PST_gapfilled_20
# performing deletions for PST_gapfilled_21
# ...

# %% [markdown]
# Within the output file, only the essential genes across all the ensembles must be selected for modification.

# %%
reps = {}
for i in range(0,500):
    gene_knockouts = pd.read_excel('../results/gene_essentiality/ensemble_essentialiity/500complete_media_ensemble_deletions.xlsx',sheet_name="PST_gapfilled_"+str(i+1))
    gene_knockouts.columns = [col for col in gene_knockouts.columns]
    reps[i] = gene_knockouts
all_biolog = pd.concat([reps[0], reps[1], reps[2], reps[3], reps[4], reps[5], reps[6], reps[7], reps[8], reps[9], reps[10], reps[11], reps[12], reps[13], reps[14], reps[15]
                        , reps[16], reps[17], reps[18], reps[19], reps[20], reps[21], reps[22], reps[23], reps[24], reps[25], reps[26], reps[27], reps[28], reps[29], reps[30]
                        , reps[31], reps[32], reps[33], reps[34], reps[35], reps[36], reps[37], reps[38], reps[39], reps[40], reps[41], reps[42], reps[43], reps[44], reps[45]
                        , reps[46], reps[47], reps[48], reps[49], reps[50], reps[51], reps[52], reps[53], reps[54], reps[55], reps[56], reps[57], reps[58], reps[59], reps[60]
                        , reps[61], reps[62], reps[63], reps[64], reps[65], reps[66], reps[67], reps[68], reps[69], reps[70], reps[71], reps[72], reps[73], reps[74], reps[75]
                        , reps[76], reps[77], reps[78], reps[79], reps[80], reps[81], reps[82], reps[83], reps[84], reps[85], reps[86], reps[87], reps[88], reps[89], reps[90]
                        , reps[91], reps[92], reps[93], reps[94], reps[95], reps[96], reps[97], reps[98], reps[99]])
all_biolog2 = pd.concat([ reps[100], reps[101], reps[102], reps[103], reps[104], reps[105], reps[106], reps[107], reps[108], reps[109], reps[110], reps[111], reps[112], reps[113], reps[114], reps[115]
                        , reps[116], reps[117], reps[118], reps[119], reps[120], reps[121], reps[122], reps[123], reps[124], reps[125], reps[126], reps[127], reps[128], reps[129], reps[130]
                        , reps[131], reps[132], reps[133], reps[134], reps[135], reps[136], reps[137], reps[138], reps[139], reps[140], reps[141], reps[142], reps[143], reps[144], reps[145]
                        , reps[431], reps[432], reps[433], reps[434], reps[435], reps[436], reps[437], reps[438], reps[439], reps[440], reps[441], reps[442], reps[443], reps[444], reps[445]
                        , reps[446], reps[447], reps[448], reps[449], reps[450], reps[451], reps[452], reps[453], reps[454], reps[455], reps[456], reps[457], reps[458], reps[459], reps[460]
                        , reps[461], reps[462], reps[463], reps[464], reps[465], reps[466], reps[467], reps[468], reps[469], reps[470], reps[471], reps[472], reps[473], reps[474], reps[475]
                        , reps[476], reps[477], reps[478], reps[479], reps[480], reps[481], reps[482], reps[483], reps[484], reps[485], reps[486], reps[487], reps[488], reps[489], reps[490]
                        , reps[491], reps[492], reps[493], reps[494], reps[495], reps[496], reps[497], reps[498], reps[499]])
final_table = pd.concat([all_biolog, all_biolog2, all_biolog3, all_biolog4, all_biolog5])
final_table.to_csv('../results/gene_essentiality/ensemble_500/complete_essentiality.csv')
df3 = final_table['growth'].groupby(final_table['ids']).unique().apply(pd.Series)
df3.to_csv('../results/gene_essentiality//ensemble_500/unique_complete.csv')

# %%
final_table = pd.concat([all_biolog, all_biolog2, all_biolog3, all_biolog4, all_biolog5])
final_table.to_csv('../results/gene_essentiality/ensemble_500/500complete_essentiality.csv')
df3 = final_table['growth'].groupby(final_table['ids']).unique().apply(pd.Series)
df3.to_csv('../results/gene_essentiality//ensemble_500/500unique_complete.csv')

# %%
reps = {}
for i in range(0,501):
    gene_knockouts = pd.read_excel('../results/gene_essentiality/ensemble_essentialiity/500gluc_media_ensemble_deletions.xlsx',sheet_name="PST_gapfilled_"+str(i+1))
    gene_knockouts.columns = [col for col in gene_knockouts.columns]
    reps[i] = gene_knockouts
all_biolog = pd.concat([reps[0], reps[1], reps[2], reps[3], reps[4], reps[5], reps[6], reps[7], reps[8], reps[9], reps[10], reps[11], reps[12], reps[13], reps[14], reps[15]
                        , reps[16], reps[17], reps[18], reps[19], reps[20], reps[21], reps[22], reps[23], reps[24], reps[25], reps[26], reps[27], reps[28], reps[29], reps[30]
                        , reps[31], reps[32], reps[33], reps[34], reps[35], reps[36], reps[37], reps[38], reps[39], reps[40], reps[41], reps[42], reps[43], reps[44], reps[45]
                        , reps[46], reps[47], reps[48], reps[49], reps[50], reps[51], reps[52], reps[53], reps[54], reps[55], reps[56], reps[57], reps[58], reps[59], reps[60]
                        , reps[61], reps[62], reps[63], reps[64], reps[65], reps[66], reps[67], reps[68], reps[69], reps[70], reps[71], reps[72], reps[73], reps[74], reps[75]
                        , reps[76], reps[77], reps[78], reps[79], reps[80], reps[81], reps[82], reps[83], reps[84], reps[85], reps[86], reps[87], reps[88], reps[89], reps[90]
                        , reps[91], reps[92], reps[93], reps[94], reps[95], reps[96], reps[97], reps[98], reps[99]])
all_biolog2 = pd.concat([ reps[100], reps[101], reps[102], reps[103], reps[104], reps[105], reps[106], reps[107], reps[108], reps[109], reps[110], reps[111], reps[112], reps[113], reps[114], reps[115]
                        , reps[116], reps[117], reps[118], reps[119], reps[120], reps[121], reps[122], reps[123], reps[124], reps[125], reps[126], reps[127], reps[128], reps[129], reps[130]
                        , reps[461], reps[462], reps[463], reps[464], reps[465], reps[466], reps[467], reps[468], reps[469], reps[470], reps[471], reps[472], reps[473], reps[474], reps[475]
                        , reps[476], reps[477], reps[478], reps[479], reps[480], reps[481], reps[482], reps[483], reps[484], reps[485], reps[486], reps[487], reps[488], reps[489], reps[490]
                        , reps[491], reps[492], reps[493], reps[494], reps[495], reps[496], reps[497], reps[498], reps[499], reps[500]])
final_table = pd.concat([all_biolog, all_biolog2, all_biolog3, all_biolog4, all_biolog5])
final_table.to_csv('../results/gene_essentiality/ensemble_500/500anderson_essentiality.csv')
df3 = final_table['growth'].groupby(final_table['ids']).unique().apply(pd.Series)
df3.to_csv('../results/gene_essentiality//ensemble_500/500unique_anderson.csv')

# %%
complete = pd.read_excel("../results/gene_essentiality/ensemble_essentialiity/")
complete_ids = [ids for ids in complete.ids]
for y in complete_ids:
    if "nan":
        pass
    else:
        print (y)
complete_gene_list=[]
for x in complete_ids:
    x = str(x)
    if 'nan' in x:
        pass
    else:
        result = re.split("frozenset\\({'", x)
    for y in result:
        if "frozenset" in y:
            pass
        else:
            complete_gene_list.append(str(y[:-3]))
pd.DataFrame(complete_gene_list)

#change this for r, so that the keggrest can use it
unique_list = []
for z in complete_gene_list:
    if z not in unique_list:
        if 'PSPTO_' in z:
            z = "pst:" + z
            unique_list.append(z)
        else: pass
    else:
        pass
listo = pd.DataFrame(unique_list)
listo.to_csv("../results/gene_essentiality/ensemble_500/complete_media/unique_complete_essential_all_for_r.csv")

# %%
complete = pd.read_excel("../results/gene_essentiality/ensemble_500/complete_media/unique_complete_essential_90_percent.xlsx")
complete_ids = [ids for ids in complete.ids]
for y in complete_ids:
    if "nan":
        pass
    else:
        print (y)
complete_gene_list=[]
for x in complete_ids:
    x = str(x)
    if 'nan' in x:
        pass
    else:
        result = re.split("frozenset\\({'", x)
    for y in result:
        if "frozenset" in y:
            pass
        else:
            complete_gene_list.append(str(y[:-3]))
pd.DataFrame(complete_gene_list)

#change this for r, so that the keggrest can use it
unique_list = []
for z in complete_gene_list:
    if z not in unique_list:
        if 'PSPTO_' in z:
            z = "pst:" + z
            unique_list.append(z)
        else: pass
    else:
        pass
listo = pd.DataFrame(unique_list)
listo.to_csv("../results/gene_essentiality/ensemble_500/complete_media/unique_complete_essential_90_for_r.csv")

# %%
complete = pd.read_excel("../results/gene_essentiality/ensemble_500/anderson_media/unique_anderson_essential_all.xlsx")
complete_ids = [ids for ids in complete.ids]
for y in complete_ids:
    if "nan":
        pass
    else:
        print (y)
complete_gene_list=[]
for x in complete_ids:
    x = str(x)
    if 'nan' in x:
        pass
    else:
        result = re.split("frozenset\\({'", x)
    for y in result:
        if "frozenset" in y:
            pass
        else:
            complete_gene_list.append(str(y[:-3]))
pd.DataFrame(complete_gene_list)

#change this for r, so that the keggrest can use it
unique_list = []
for z in complete_gene_list:
    if z not in unique_list:
        if 'PSPTO_' in z:
            z = "pst:" + z
            unique_list.append(z)
        else: pass
    else:
        pass
listo = pd.DataFrame(unique_list)
listo.to_csv("../results/gene_essentiality/ensemble_500/anderson_media/unique_anderson_essential_all_for_r.csv")

# %%
complete = pd.read_excel("../results/gene_essentiality/ensemble_500/anderson_media/unique_anderson_essential_90_percent.xlsx")
complete_ids = [ids for ids in complete.ids]
for y in complete_ids:
    if "nan":
        pass
    else:
        print (y)
complete_gene_list=[]
for x in complete_ids:
    x = str(x)
    if 'nan' in x:
        pass
    else:
        result = re.split("frozenset\\({'", x)
    for y in result:
        if "frozenset" in y:
            pass
        else:
            complete_gene_list.append(str(y[:-3]))
pd.DataFrame(complete_gene_list)

#change this for r, so that the keggrest can use it
unique_list = []
for z in complete_gene_list:
    if z not in unique_list:
        if 'PSPTO_' in z:
            z = "pst:" + z
            unique_list.append(z)
        else: pass
    else:
        pass
listo = pd.DataFrame(unique_list)
listo.to_csv("../results/gene_essentiality/ensemble_500/anderson_media/unique_anderson_essential_90_for_r.csv")

# %%
complete = pd.read_excel("../results/gene_essentiality/ensemble_500/gluc_media/unique_gluc_essential_all.xlsx")
complete_ids = [ids for ids in complete.ids]
for y in complete_ids:
    if "nan":
        pass
    else:
        print (y)
complete_gene_list=[]
for x in complete_ids:
    x = str(x)
    if 'nan' in x:
        pass
    else:
        result = re.split("frozenset\\({'", x)
    for y in result:
        if "frozenset" in y:
            pass
        else:
            complete_gene_list.append(str(y[:-3]))
pd.DataFrame(complete_gene_list)

#change this for r, so that the keggrest can use it
unique_list = []
for z in complete_gene_list:
    if z not in unique_list:
        if 'PSPTO_' in z:
            z = "pst:" + z
            unique_list.append(z)
        else: pass
    else:
        pass
listo = pd.DataFrame(unique_list)
listo.to_csv("../results/gene_essentiality/ensemble_500/gluc_media/unique_gluc_essential_all_for_r.csv")

# %%
complete = pd.read_excel("../results/gene_essentiality/ensemble_500/gluc_media/unique_gluc_essential_90_percent.xlsx")
complete_ids = [ids for ids in complete.ids]
for y in complete_ids:
    if "nan":
        pass
    else:
        print (y)
complete_gene_list=[]
for x in complete_ids:
    x = str(x)
    if 'nan' in x:
        pass
    else:
        result = re.split("frozenset\\({'", x)
    for y in result:
        if "frozenset" in y:
            pass
        else:
            complete_gene_list.append(str(y[:-3]))
pd.DataFrame(complete_gene_list)

#change this for r, so that the keggrest can use it
unique_list = []
for z in complete_gene_list:
    if z not in unique_list:
        if 'PSPTO_' in z:
            z = "pst:" + z
            unique_list.append(z)
        else: pass
    else:
        pass
listo = pd.DataFrame(unique_list)
listo.to_csv("../results/gene_essentiality/ensemble_500/gluc_media/unique_gluc_essential_90_for_r.csv")

# %%
complete = pd.read_excel("../results/gene_essentiality/ensemble_500/glut_media/unique_glut_essential_all.xlsx")
complete_ids = [ids for ids in complete.ids]
for y in complete_ids:
    if "nan":
        pass
    else:
        print (y)
complete_gene_list=[]
for x in complete_ids:
    x = str(x)
    if 'nan' in x:
        pass
    else:
        result = re.split("frozenset\\({'", x)
    for y in result:
        if "frozenset" in y:
            pass
        else:
            complete_gene_list.append(str(y[:-3]))
pd.DataFrame(complete_gene_list)

#change this for r, so that the keggrest can use it
unique_list = []
for z in complete_gene_list:
    if z not in unique_list:
        if 'PSPTO_' in z:
            z = "pst:" + z
            unique_list.append(z)
        else: pass
    else:
        pass
listo = pd.DataFrame(unique_list)
listo.to_csv("../results/gene_essentiality/ensemble_500/glut_media/unique_glut_essential_all_for_r.csv")

# %%
complete = pd.read_excel("../results/gene_essentiality/ensemble_500/glut_media/unique_glut_essential_90_percent.xlsx")
complete_ids = [ids for ids in complete.ids]
for y in complete_ids:
    if "nan":
        pass
    else:
        print (y)
complete_gene_list=[]
for x in complete_ids:
    x = str(x)
    if 'nan' in x:
        pass
    else:
        result = re.split("frozenset\\({'", x)
    for y in result:
        if "frozenset" in y:
            pass
        else:
            complete_gene_list.append(str(y[:-3]))
pd.DataFrame(complete_gene_list)

#change this for r, so that the keggrest can use it
unique_list = []
for z in complete_gene_list:
    if z not in unique_list:
        if 'PSPTO_' in z:
            z = "pst:" + z
            unique_list.append(z)
        else: pass
    else:
        pass
listo = pd.DataFrame(unique_list)
listo.to_csv("../results/gene_essentiality/ensemble_500/glut_media/unique_glut_essential_90_for_r.csv")

# %%
final_table = pd.read_csv('../results/gene_essentiality/ensemble_500/gluc_essentiality.csv')
df3 = final_table['growth'].groupby(final_table['ids']).unique().apply(pd.Series)
df3.to_csv('../results/gene_essentiality//ensemble_500/unique_gluc.csv')

# %%
gene_ass = pd.read_excel('../results/gene_associations_to_add.xlsx')

# %%
ensemble.base_model.reactions.rxn38886_c.gene_reaction_rule = "PSPTO_0817 or PSPTO_1118 or PSPTO_3007 or PSPTO_4225"
ensemble.base_model.reactions.rxn08434_c.gene_reaction_rule = "PSPTO_2168 or PSPTO_5100"
ensemble.base_model.reactions.rxn05214_c.gene_reaction_rule = "PSPTO_0062"
ensemble.base_model.reactions.rxn00848_c.gene_reaction_rule = "PSPTO_4116"
ensemble.base_model.reactions.rxn10620_c.gene_reaction_rule = "PSPTO_4798"
ensemble.base_model.reactions.rxn37695_c.gene_reaction_rule = "PSPTO_0103 and PSPTO_0774" 
ensemble.base_model.reactions.rxn02283_c.gene_reaction_rule = "PSPTO_5171 and PSPTO_5278" 
ensemble.base_model.reactions.rxn01122_c.gene_reaction_rule = "PSPTO_1302" 
ensemble.base_model.reactions.rxn27430_c.gene_reaction_rule = "PSPTO_2373" 
ensemble.base_model.reactions.rxn27430_c.gene_reaction_rule = "PSPTO_3976"

# %%
ass_dict = {}
for x in gene_ass.itertuples():
    ass_dict[x.rxn[0:10]] = x.gene

# %%
for key, val in ass_dict.items():
    if key in ensemble.base_model.reactions:
        ensemble.base_model.reactions.get_by_id(key).gene_reaction_rule = val

# %%
len(ensemble.base_model.genes)
# Out:
# 912

# %%
save_dir = ("../results/ensembles/pto_ensemble_100_genes_added_4.pickle")
ensemble.to_pickle(save_dir)

# %%
from pickle import load
with open("../results/ensembles/pto_ensemble_100_genes_added_e3.pickle", 'rb') as infile:
    ensemble = load(infile)

# %%
for key, val in ass_dict.items():
    if key in ensemble.base_model.reactions:
        ensemble.base_model.reactions.get_by_id(key).gene_reaction_rule = val

# %%
gene_list = []
for gene in ensemble.base_model.genes:
    gene_list.append(gene.id)

# %%
gene_list
# Out:
# ['PSPTO_0722',
#  'PSPTO_1361',
#  'PSPTO_0982',
#  'PSPTO_3860',
#  'PSPTO_0981',
#  'PSPTO_5005',
#  'PSPTO_3862',
#  'PSPTO_4921',
#  'PSPTO_4290',
#  'PSPTO_4235',
#  'PSPTO_5251',
#  'PSPTO_0691',
#  'PSPTO_3902',
#  'PSPTO_1428',
#  'PSPTO_0128',
#  'PSPTO_1349',
#  'PSPTO_1455',
#  'PSPTO_0230',
#  'PSPTO_3793',
#  'PSPTO_2106',
#  'PSPTO_5121',
#  'PSPTO_4254',
#  'PSPTO_0549',
#  'PSPTO_1509',
#  'PSPTO_0923',
#  'PSPTO_4895',
#  'PSPTO_4891',
#  'PSPTO_4894',
#  'PSPTO_4828',
#  'PSPTO_4501',
#  'PSPTO_4502',
#  'PSPTO_1430',
#  'PSPTO_1536',
#  'PSPTO_5521',
#  'PSPTO_0383',
#  'PSPTO_0598',
#  'PSTPO_0757',
#  'PSPTO_4795',
#  'PSPTO_1562',
#  'PSPTO_5401',
#  'PSPTO_4922',
#  'PSPTO_1990',
#  'PSPTO_0490',
#  'PSPTO_4965',
#  'PSPTO_5068',
#  'PSPTO_2292',
#  'PSPTO_4337',
#  'PSPTO_2680',
#  'PSPTO_3924',
#  'PSPTO_5134',
#  'PSPTO_1886',
#  'PSPTO_1169',
#  'PSPTO_0957',
#  'PSPTO_0800',
#  'PSPTO_3757',
#  'PSPTO_3644',
#  'PSPTO_1881',
#  'PSPTO_0359',
# ...

# %%
import pandas as pd
file_path = '../results/gene_essentiality/ensemble_essentialiity/'
patric_path = file_path + "PATRIC_id_mapping.csv"
patric = pd.read_csv(patric_path)
patric_dict = patric.to_dict(orient = 'index')
complete_list = []
complete_list_mod = [] 
for x in gene_list:
    if "PSPTO_" in x:
        complete_list.append(x)
    else:
        x = "fig|" + x
        complete_list_mod.append(x)
#print (complete_gene_list)


new_pat=pd.Series(patric.Target.values,index=patric.Source).to_dict()
patric_genes_essential = []
for key,value in new_pat.items():
    if key in complete_list_mod:
        print (key, value)
        patric_genes_essential.append(value)
complete_and_patric_gene_list = patric_genes_essential + complete_list

unique_list = []
for z in complete_and_patric_gene_list:
    if z not in unique_list:
        if 'PSPTO_' in z:
            z = "pst:" + z
            unique_list.append(z)
        else: pass
    else:
        pass
listo = pd.DataFrame(unique_list)
listo.to_csv("../results/all_genes_for_orthologies_for_r.csv")

#after r, use the next cell
# Out:
# fig|223283.9.peg.1 PSPTO_0001
# fig|223283.9.peg.1290 PSPTO_1268
# fig|223283.9.peg.1455 PSPTO_1435
# fig|223283.9.peg.1494 PSPTO_1473
# fig|223283.9.peg.1497 PSPTO_1476
# fig|223283.9.peg.1522 PSPTO_1501
# fig|223283.9.peg.1560 PSPTO_1534
# fig|223283.9.peg.1575 PSPTO_1549
# fig|223283.9.peg.1577 PSPTO_1551
# fig|223283.9.peg.1663 PSPTO_1639
# fig|223283.9.peg.1773 PSPTO_1745
# fig|223283.9.peg.184 PSPTO_0178
# fig|223283.9.peg.1841 PSPTO_1812
# fig|223283.9.peg.1842 PSPTO_1813
# fig|223283.9.peg.1871 PSPTO_1842
# fig|223283.9.peg.190 PSPTO_0184
# fig|223283.9.peg.191 PSPTO_0185
# fig|223283.9.peg.2 PSPTO_0002
# fig|223283.9.peg.2197 PSPTO_2166
# fig|223283.9.peg.2413 PSPTO_2378
# fig|223283.9.peg.2415 PSPTO_2380
# fig|223283.9.peg.2416 PSPTO_2381
# fig|223283.9.peg.2417 PSPTO_2382
# fig|223283.9.peg.2418 PSPTO_2383
# fig|223283.9.peg.2657 PSPTO_2611
# fig|223283.9.peg.3424 PSPTO_3345
# fig|223283.9.peg.3599 PSPTO_3514
# fig|223283.9.peg.3735 PSPTO_3646
# ...

# %%
listo
# Out:
#                   0
# 0    pst:PSPTO_0001
# 1    pst:PSPTO_1268
# 2    pst:PSPTO_1435
# 3    pst:PSPTO_1473
# 4    pst:PSPTO_1476
# 5    pst:PSPTO_1501
# 6    pst:PSPTO_1534
# 7    pst:PSPTO_1549
# 8    pst:PSPTO_1551
# 9    pst:PSPTO_1639
# 10   pst:PSPTO_1745
# 11   pst:PSPTO_0178
# 12   pst:PSPTO_1812
# 13   pst:PSPTO_1813
# 14   pst:PSPTO_1842
# 15   pst:PSPTO_0184
# 16   pst:PSPTO_0185
# 17   pst:PSPTO_0002
# 18   pst:PSPTO_2166
# 19   pst:PSPTO_2378
# 20   pst:PSPTO_2380
# 21   pst:PSPTO_2381
# 22   pst:PSPTO_2382
# 23   pst:PSPTO_2383
# 24   pst:PSPTO_2611
# 25   pst:PSPTO_3345
# 26   pst:PSPTO_3514
# 27   pst:PSPTO_3646
# 28   pst:PSPTO_3658
# 29   pst:PSPTO_3721
# ..              ...
# 873  pst:PSPTO_5064
# 874  pst:PSPTO_4421
# 875  pst:PSPTO_4984
# 876  pst:PSPTO_5284
# 877  pst:PSPTO_5490
# 878  pst:PSPTO_4943
# 879  pst:PSPTO_5378
# 880  pst:PSPTO_3669
# 881  pst:PSPTO_3493
# 882  pst:PSPTO_0967
# 883  pst:PSPTO_1798
# 884  pst:PSPTO_2140
# 885  pst:PSPTO_2141
# ...
